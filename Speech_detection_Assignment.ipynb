# %% [markdown]
# # <font color='red'> Spoken Digit Recognition</font>

# %% [markdown]
# In this notebook, You will do Spoken Digit Recognition.
#
# Input - speech signal, output - digit number
#
#
#
# It contains
#
# 1. Reading the dataset. and Preprocess the data set. Detailed instrctions are given below. You have to write the code in the same cell which contains the instrction.
# 2. Training the LSTM with RAW data
# 3. Converting to spectrogram and Training the LSTM network
# 4. Creating the augmented data and doing step 2 and 3 again.
#
# <font size=5>Instructions:</font>
#
#     1. Don't change any Grader Functions. Don't manipulate any Grader functions. If you manipulate any, it will be considered as plagiarised.
#
#     2. Please read the instructions on the code cells and markdown cells. We will explain what to write.
#
#     3. Please return outputs in the same format what we asked. Eg. Don't return List of we are asking for a numpy array.
#
#     4. Please read the external links that we are given so that you will learn the concept behind the code that you are writing.
#
#     5. We are giving instructions at each section if necessary, please follow them.
#
# <font size=5>Every Grader function has to return True. </font>

# %%
import numpy as np
import pandas as pd
import librosa
import librosa.display
import os
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix, f1_score, classification_report
import tensorflow as tf
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import LearningRateScheduler, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.layers import Input, BatchNormalization, Dropout, LSTM, Dense, AveragePooling2D, GlobalAveragePooling2D, AveragePooling1D, InputLayer, GlobalAveragePooling1D
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.utils import plot_model
tf.keras.backend.clear_session()
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import seaborn as sns
import glob
from joblib import Parallel, delayed
import time
import librosa.display
from collections import Counter
##if you need any imports you can do that here.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# We shared recordings.zip, please unzip those.

# %%
#read the all file names in the recordings folder given by us
#(if you get entire path, it is very useful in future)
#save those files names as list in "all_files"
path = '/content/drive/MyDrive/Audio_Spoken_Digit/recordings'
all_files = []
for files in os.listdir(path):
    names = os.path.join(path, files)
    all_files.append(names)
all_files
# Out:
# ['/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_jackson_20.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_theo_15.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_yweweler_1.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_yweweler_10.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_jackson_34.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_jackson_12.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_yweweler_8.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_jackson_6.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_jackson_21.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_yweweler_2.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_yweweler_8.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_jackson_46.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_jackson_6.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_theo_10.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_nicolas_10.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_yweweler_14.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_jackson_40.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_theo_13.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_theo_8.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_nicolas_23.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_yweweler_39.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_theo_40.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_yweweler_22.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_yweweler_15.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_theo_27.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_theo_29.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_nicolas_32.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_jackson_16.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_theo_11.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_yweweler_15.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_nicolas_15.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_yweweler_48.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_theo_15.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_jackson_29.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_nicolas_9.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_theo_27.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_yweweler_9.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_jackson_3.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_yweweler_14.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_jackson_17.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_nicolas_38.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_theo_43.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_yweweler_36.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_theo_4.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_yweweler_17.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_jackson_25.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_yweweler_13.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_yweweler_19.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_jackson_13.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_theo_37.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_nicolas_27.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_jackson_42.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_yweweler_23.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_yweweler_9.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_jackson_6.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_theo_7.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_jackson_6.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_nicolas_42.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_jackson_30.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_jackson_24.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_theo_32.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_jackson_37.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_yweweler_12.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_nicolas_42.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_theo_1.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_jackson_43.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_jackson_25.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_nicolas_18.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_jackson_11.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_theo_2.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_nicolas_37.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_theo_25.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_jackson_0.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_yweweler_8.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_jackson_4.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_theo_14.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_jackson_34.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_yweweler_26.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_nicolas_31.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_nicolas_5.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_nicolas_29.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_theo_12.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_nicolas_43.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_jackson_30.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_jackson_40.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_jackson_16.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_nicolas_34.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_yweweler_16.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_theo_44.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_yweweler_11.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_theo_38.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_nicolas_23.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_theo_5.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_theo_3.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_theo_0.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_nicolas_3.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_yweweler_33.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_yweweler_46.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_jackson_20.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_yweweler_45.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_jackson_47.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_nicolas_33.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_jackson_4.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_nicolas_17.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_jackson_32.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_jackson_11.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_yweweler_9.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_yweweler_7.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_yweweler_0.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_yweweler_27.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_jackson_19.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_jackson_12.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_jackson_23.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_yweweler_46.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_yweweler_39.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_jackson_1.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_theo_25.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_yweweler_13.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_nicolas_27.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_yweweler_32.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_nicolas_45.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_theo_35.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_nicolas_6.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_theo_10.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_yweweler_1.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_theo_25.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_nicolas_45.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_yweweler_34.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_yweweler_16.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_theo_23.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_nicolas_35.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_jackson_24.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_theo_49.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_theo_40.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_yweweler_21.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_theo_32.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_jackson_24.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_yweweler_19.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_jackson_33.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_yweweler_29.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_yweweler_36.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_theo_33.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_theo_35.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_yweweler_17.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_theo_43.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_nicolas_30.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_jackson_14.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_theo_13.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_theo_40.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_jackson_48.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_nicolas_13.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_theo_4.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_jackson_43.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_yweweler_24.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_nicolas_46.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_jackson_40.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_theo_26.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_nicolas_18.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_theo_18.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_yweweler_14.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_theo_44.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_yweweler_23.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_jackson_43.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_jackson_38.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_jackson_42.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_jackson_48.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_nicolas_8.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_yweweler_2.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_theo_17.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_nicolas_28.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_yweweler_32.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_nicolas_45.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_nicolas_38.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_jackson_24.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_yweweler_0.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_jackson_10.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_theo_5.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_jackson_8.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_jackson_13.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_yweweler_30.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_nicolas_8.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_yweweler_41.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_nicolas_22.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_yweweler_44.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_theo_22.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_theo_8.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_nicolas_1.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_theo_24.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_nicolas_5.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_nicolas_17.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_nicolas_5.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_jackson_6.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_jackson_32.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_jackson_16.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_jackson_40.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_jackson_0.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_yweweler_43.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_yweweler_40.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_theo_23.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_yweweler_33.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_yweweler_27.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_nicolas_47.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_theo_31.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_theo_5.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_nicolas_19.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_yweweler_35.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_jackson_8.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_yweweler_42.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_jackson_49.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_jackson_42.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_jackson_7.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_yweweler_49.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_theo_13.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_nicolas_10.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_nicolas_24.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_nicolas_30.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_nicolas_40.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_jackson_1.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_nicolas_19.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_nicolas_5.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_yweweler_9.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_nicolas_44.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_theo_41.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_nicolas_29.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_theo_14.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_theo_17.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_yweweler_28.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_nicolas_12.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_theo_48.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_jackson_8.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_jackson_8.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_jackson_22.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_nicolas_49.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_jackson_33.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_nicolas_11.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_jackson_18.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_nicolas_9.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_jackson_43.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_jackson_5.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_yweweler_47.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_nicolas_35.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_nicolas_14.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_nicolas_45.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_nicolas_46.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_jackson_42.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_yweweler_30.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_jackson_28.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_yweweler_20.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_nicolas_0.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_theo_0.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_nicolas_46.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_jackson_28.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_nicolas_12.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_yweweler_46.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_jackson_17.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_nicolas_6.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_yweweler_45.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_theo_38.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_jackson_32.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_yweweler_18.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_jackson_37.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_jackson_11.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_yweweler_41.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_theo_1.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_jackson_42.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_theo_17.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_yweweler_44.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_nicolas_21.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_yweweler_22.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_yweweler_0.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_theo_19.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_nicolas_27.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_nicolas_5.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_theo_18.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_jackson_48.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_jackson_37.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_jackson_45.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_theo_30.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_nicolas_27.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_jackson_26.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_nicolas_40.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_jackson_27.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_yweweler_22.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_theo_10.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_nicolas_1.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_jackson_29.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_nicolas_0.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_jackson_47.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_nicolas_17.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_nicolas_25.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_jackson_43.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_jackson_9.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_yweweler_46.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_nicolas_22.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_theo_2.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_nicolas_13.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_jackson_15.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_jackson_10.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_nicolas_32.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_theo_18.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_jackson_0.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_theo_4.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_jackson_35.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_jackson_34.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_yweweler_4.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_jackson_38.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_nicolas_0.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_jackson_26.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_yweweler_39.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_yweweler_39.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_jackson_38.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_jackson_46.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_nicolas_13.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_jackson_0.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_yweweler_37.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_theo_27.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_jackson_46.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_theo_45.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_theo_4.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_nicolas_3.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_nicolas_10.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_nicolas_36.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_theo_32.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_jackson_3.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_nicolas_31.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_yweweler_1.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_yweweler_5.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_jackson_10.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_nicolas_47.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_theo_12.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_jackson_4.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_yweweler_32.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_jackson_31.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_nicolas_1.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_theo_25.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_theo_23.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_nicolas_31.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_jackson_27.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_theo_46.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_nicolas_9.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_jackson_23.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_yweweler_36.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_jackson_9.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_yweweler_3.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_theo_24.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_nicolas_23.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_jackson_19.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_theo_36.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_nicolas_29.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_theo_41.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_jackson_20.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_nicolas_21.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_theo_36.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_yweweler_10.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_jackson_12.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_nicolas_39.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_jackson_17.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_jackson_13.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_jackson_14.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_yweweler_48.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_jackson_25.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_jackson_32.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_nicolas_22.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_jackson_23.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_theo_0.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_yweweler_17.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_nicolas_25.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_nicolas_30.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_jackson_42.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_jackson_17.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_nicolas_6.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_nicolas_24.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_yweweler_48.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_theo_12.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_theo_35.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_yweweler_44.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_yweweler_4.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_jackson_18.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_theo_39.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_yweweler_3.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_jackson_28.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_jackson_10.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_jackson_32.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_nicolas_48.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_theo_38.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_jackson_49.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_nicolas_29.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_theo_30.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_jackson_36.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_jackson_37.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_jackson_39.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_yweweler_34.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_yweweler_14.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_yweweler_42.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_nicolas_36.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_jackson_31.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_yweweler_40.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_jackson_41.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_jackson_24.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_theo_40.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_yweweler_42.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_nicolas_25.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_nicolas_24.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_theo_41.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_theo_14.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_yweweler_7.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_yweweler_29.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_jackson_20.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_nicolas_49.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_theo_19.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_theo_37.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_nicolas_32.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_theo_21.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_theo_45.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_nicolas_14.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_jackson_49.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_nicolas_5.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_yweweler_28.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_nicolas_38.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_nicolas_45.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_theo_20.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_theo_6.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_theo_5.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_nicolas_22.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_yweweler_15.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_nicolas_9.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_yweweler_25.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_jackson_19.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_jackson_1.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_nicolas_13.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_jackson_24.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_theo_33.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_theo_43.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_yweweler_10.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_theo_6.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_theo_31.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_theo_33.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_jackson_15.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_theo_1.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_theo_14.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_theo_38.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_nicolas_44.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_nicolas_8.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_theo_34.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_nicolas_36.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_theo_22.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_nicolas_38.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_yweweler_39.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_jackson_29.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_jackson_44.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_jackson_13.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_nicolas_26.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_nicolas_9.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_theo_19.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_yweweler_13.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_theo_44.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_jackson_10.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_yweweler_28.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_jackson_12.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_nicolas_15.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_theo_42.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_yweweler_7.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_nicolas_43.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_jackson_22.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_yweweler_37.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_nicolas_22.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_jackson_34.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_theo_44.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_theo_30.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_jackson_30.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_nicolas_28.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_theo_8.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_theo_3.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_nicolas_41.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_theo_36.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_jackson_21.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_theo_22.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_yweweler_18.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_yweweler_9.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_yweweler_49.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_yweweler_15.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_jackson_32.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_yweweler_3.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_nicolas_43.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_jackson_40.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_jackson_28.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_nicolas_24.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_jackson_39.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_jackson_18.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_nicolas_34.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_jackson_1.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_theo_2.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_yweweler_37.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_nicolas_44.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_jackson_24.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_yweweler_36.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_theo_15.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_nicolas_31.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_jackson_29.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_theo_42.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_theo_11.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_theo_2.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_theo_21.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_jackson_29.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_jackson_34.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_nicolas_4.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_nicolas_19.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_theo_45.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_theo_12.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_nicolas_33.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_yweweler_46.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_yweweler_26.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_theo_1.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_yweweler_36.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_nicolas_2.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_theo_38.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_theo_32.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_nicolas_15.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_yweweler_25.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_nicolas_30.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_nicolas_33.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_yweweler_22.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_yweweler_43.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_theo_6.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_nicolas_3.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_yweweler_6.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_yweweler_1.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_theo_15.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_jackson_49.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_yweweler_28.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_theo_36.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_yweweler_29.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_jackson_37.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_jackson_44.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_theo_28.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_yweweler_8.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_yweweler_18.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_yweweler_21.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_theo_31.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_nicolas_26.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_yweweler_45.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_yweweler_21.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_yweweler_35.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_yweweler_21.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_theo_11.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_nicolas_11.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_theo_33.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_nicolas_47.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_theo_13.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_theo_10.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_jackson_25.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_theo_36.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_nicolas_29.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_jackson_4.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_yweweler_15.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_theo_23.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_yweweler_33.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_jackson_36.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_nicolas_30.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_nicolas_27.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_theo_1.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_nicolas_42.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_jackson_33.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_yweweler_3.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_nicolas_41.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_nicolas_28.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_yweweler_27.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_theo_39.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_theo_29.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_jackson_44.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_nicolas_37.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_theo_36.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_theo_22.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_jackson_3.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_yweweler_28.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_yweweler_8.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_nicolas_41.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_jackson_30.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_yweweler_31.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_jackson_35.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_nicolas_47.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_jackson_23.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_theo_33.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_theo_45.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_nicolas_41.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_jackson_7.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_theo_35.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_jackson_42.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_yweweler_10.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_yweweler_5.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_jackson_45.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_nicolas_0.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_jackson_1.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_jackson_30.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_theo_47.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_yweweler_27.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_nicolas_15.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_theo_28.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_jackson_21.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_theo_34.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_theo_20.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_nicolas_49.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_yweweler_16.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_jackson_23.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_jackson_7.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_yweweler_20.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_jackson_34.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_theo_39.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_theo_37.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_yweweler_30.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_jackson_23.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_jackson_20.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_theo_5.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_yweweler_37.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_jackson_18.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_theo_48.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_theo_20.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_yweweler_40.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_yweweler_22.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_jackson_19.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_yweweler_31.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_yweweler_2.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_yweweler_46.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_nicolas_16.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_nicolas_45.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_jackson_11.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_yweweler_5.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_theo_7.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_yweweler_3.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_jackson_31.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_yweweler_43.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_yweweler_17.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_theo_6.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_yweweler_24.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_yweweler_9.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_yweweler_16.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_jackson_25.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_theo_25.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_yweweler_13.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_theo_28.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_nicolas_24.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_nicolas_7.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_theo_32.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_nicolas_48.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_nicolas_24.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_theo_35.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_nicolas_16.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_nicolas_26.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_nicolas_1.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_nicolas_13.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_jackson_7.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_nicolas_41.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_nicolas_35.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_nicolas_27.wav',
# ...
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_jackson_28.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_yweweler_46.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_nicolas_46.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_nicolas_36.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_nicolas_3.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_yweweler_36.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_yweweler_23.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_jackson_13.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_theo_16.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_nicolas_34.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_theo_36.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_theo_37.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_yweweler_30.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_jackson_5.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_theo_23.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_nicolas_12.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_nicolas_19.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_theo_7.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_jackson_44.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_theo_29.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_yweweler_49.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_theo_42.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_nicolas_39.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_yweweler_32.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_theo_26.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_yweweler_10.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_yweweler_2.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_jackson_48.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_yweweler_37.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_theo_45.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_yweweler_4.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_jackson_23.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_theo_6.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_yweweler_18.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_theo_9.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_yweweler_41.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_nicolas_37.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_jackson_36.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_nicolas_32.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_theo_12.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_jackson_38.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_nicolas_3.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_yweweler_10.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_nicolas_20.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_yweweler_30.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_jackson_41.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_jackson_27.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_theo_27.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_theo_19.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_jackson_9.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_yweweler_41.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_yweweler_27.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_nicolas_28.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_nicolas_46.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_nicolas_43.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_jackson_49.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_jackson_13.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_nicolas_9.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_jackson_46.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_yweweler_14.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_theo_29.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_yweweler_35.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_theo_29.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_nicolas_48.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_jackson_39.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_yweweler_27.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_jackson_15.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_theo_9.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_theo_9.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_yweweler_36.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_yweweler_27.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_yweweler_31.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_theo_4.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_jackson_0.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_jackson_43.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_theo_28.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_jackson_39.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_theo_39.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_jackson_48.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_yweweler_22.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_theo_49.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_nicolas_2.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_theo_16.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_nicolas_14.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_jackson_32.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_jackson_32.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_yweweler_19.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_nicolas_5.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_theo_8.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_yweweler_38.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_yweweler_20.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_jackson_22.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_theo_8.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_yweweler_5.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_theo_46.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_nicolas_35.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_nicolas_16.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_jackson_2.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_nicolas_42.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_nicolas_19.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_theo_9.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_jackson_22.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_jackson_19.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_jackson_11.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_jackson_47.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_yweweler_43.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_yweweler_19.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_theo_12.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_nicolas_44.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_nicolas_7.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_nicolas_11.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_yweweler_27.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_jackson_4.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_nicolas_23.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_theo_8.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_nicolas_3.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_jackson_30.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_theo_6.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_yweweler_17.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_theo_27.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_nicolas_30.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_nicolas_32.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_yweweler_32.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_jackson_27.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_jackson_22.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_theo_9.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_yweweler_35.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_yweweler_31.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_nicolas_2.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_jackson_41.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_nicolas_4.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_yweweler_42.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_yweweler_26.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_yweweler_3.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_nicolas_18.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_theo_17.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_jackson_43.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_yweweler_6.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_yweweler_0.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_yweweler_38.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_jackson_10.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_jackson_48.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_theo_41.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_jackson_26.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_jackson_3.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_nicolas_17.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_jackson_46.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_jackson_46.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_yweweler_35.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_jackson_5.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_jackson_8.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_theo_2.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_yweweler_21.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_yweweler_25.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_jackson_36.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_nicolas_30.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_theo_26.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_nicolas_39.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_theo_29.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_jackson_19.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_nicolas_38.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_jackson_49.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_yweweler_40.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_theo_26.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_theo_46.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_nicolas_38.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_nicolas_23.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_yweweler_38.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_theo_36.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_jackson_47.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_yweweler_35.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_yweweler_45.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_jackson_19.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_jackson_46.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_nicolas_0.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_yweweler_39.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_yweweler_24.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_nicolas_48.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_jackson_35.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_yweweler_41.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_yweweler_41.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_jackson_27.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_nicolas_6.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_theo_7.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_jackson_0.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_yweweler_15.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_yweweler_21.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_theo_48.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_yweweler_41.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_yweweler_26.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_nicolas_48.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_theo_48.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_nicolas_39.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_theo_20.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_jackson_19.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_theo_13.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_jackson_8.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_jackson_42.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/2_nicolas_35.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_yweweler_12.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/5_nicolas_11.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/3_nicolas_3.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_jackson_6.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_theo_44.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_jackson_21.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/4_jackson_41.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_theo_13.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_jackson_14.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_jackson_0.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_jackson_38.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/0_theo_41.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/8_yweweler_30.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_yweweler_45.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/9_theo_31.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/6_theo_22.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/7_yweweler_34.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_theo_42.wav',
#  '/content/drive/MyDrive/Audio_Spoken_Digit/recordings/1_nicolas_46.wav',
#  ...]

# %% [markdown]
# <font size=4>Grader function 1 </font>

# %%
def grader_files():
    temp = len(all_files)==2000
    temp1 = all([x[-3:]=="wav" for x in all_files])
    temp = temp and temp1
    return temp
grader_files()
# Out:
# True

# %% [markdown]
# Create a dataframe(name=df_audio) with two columns(path, label).
# You can get the label from the first letter of name.
# Eg: 0_jackson_0 --> 0
# 0_jackson_43 --> 0

# %%
#Create a dataframe(name=df_audio) with two columns(path, label).   
#You can get the label from the first letter of name.  
#Eg: 0_jackson_0 --> 0  
#0_jackson_43 --> 0
label = []
for files in os.listdir(path):
    label.append(files[0])
len(label)
# Out:
# 2000

# %%
df_audio = pd.DataFrame(list(zip(all_files, label)), columns = ['path', 'label'])
df_audio
# Out:
#                                                    path label
# 0     /content/drive/MyDrive/Audio_Spoken_Digit/reco...     7
# 1     /content/drive/MyDrive/Audio_Spoken_Digit/reco...     3
# 2     /content/drive/MyDrive/Audio_Spoken_Digit/reco...     0
# 3     /content/drive/MyDrive/Audio_Spoken_Digit/reco...     0
# 4     /content/drive/MyDrive/Audio_Spoken_Digit/reco...     9
# ...                                                 ...   ...
# 1995  /content/drive/MyDrive/Audio_Spoken_Digit/reco...     2
# 1996  /content/drive/MyDrive/Audio_Spoken_Digit/reco...     3
# 1997  /content/drive/MyDrive/Audio_Spoken_Digit/reco...     3
# 1998  /content/drive/MyDrive/Audio_Spoken_Digit/reco...     0
# 1999  /content/drive/MyDrive/Audio_Spoken_Digit/reco...     4
#
# [2000 rows x 2 columns]

# %%
df_audio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   path    2000 non-null   object
#  1   label   2000 non-null   object
# dtypes: object(2)
# memory usage: 31.4+ KB

# %% [markdown]
# ## Exploring the sound dataset

# %%
#It is a good programming practise to explore the dataset that you are dealing with. This dataset is unique in itself because it has sounds as input
#https://colab.research.google.com/github/Tyler-Hilbert/AudioProcessingInPythonWorkshop/blob/master/AudioProcessingInPython.ipynb
#visualize the data and write code to play 2-3 sound samples in the notebook for better understanding.
#please go through the following reference video https://www.youtube.com/watch?v=37zCgCdV468

# %%
# Count of Labels.
total = len(df_audio)
print(Counter(df_audio['label']))
ax = sns.countplot(df_audio['label'])
for p in ax.patches:
  ax.annotate('{}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+5))

ax.yaxis.set_ticks(np.linspace(0, total, 11))
plt.grid(True)
plt.title("Label Counts")
plt.show()
# Out:
# Counter({'2': 200, '6': 200, '7': 200, '9': 200, '0': 200, '3': 200, '5': 200, '1': 200, '8': 200, '4': 200})
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## Creating dataframe

# %%
#Create a dataframe(name=df_audio) with two columns(path, label).   
#You can get the label from the first letter of name.  
#Eg: 0_jackson_0 --> 0  
#0_jackson_43 --> 0

label = []
for files in os.listdir(path):
    label.append(files[0])
len(label)
# Out:
# 2000

# %%
df_audio = pd.DataFrame(list(zip(all_files, label)), columns = ['path', 'label'])
df_audio
# Out:
#                                                    path label
# 0     /content/drive/MyDrive/Audio_Spoken_Digit/reco...     7
# 1     /content/drive/MyDrive/Audio_Spoken_Digit/reco...     3
# 2     /content/drive/MyDrive/Audio_Spoken_Digit/reco...     0
# 3     /content/drive/MyDrive/Audio_Spoken_Digit/reco...     0
# 4     /content/drive/MyDrive/Audio_Spoken_Digit/reco...     9
# ...                                                 ...   ...
# 1995  /content/drive/MyDrive/Audio_Spoken_Digit/reco...     2
# 1996  /content/drive/MyDrive/Audio_Spoken_Digit/reco...     3
# 1997  /content/drive/MyDrive/Audio_Spoken_Digit/reco...     3
# 1998  /content/drive/MyDrive/Audio_Spoken_Digit/reco...     0
# 1999  /content/drive/MyDrive/Audio_Spoken_Digit/reco...     4
#
# [2000 rows x 2 columns]

# %%
#info
df_audio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   path    2000 non-null   object
#  1   label   2000 non-null   object
# dtypes: object(2)
# memory usage: 31.4+ KB

# %%
#info
df_audio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   path    2000 non-null   object
#  1   label   2000 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 31.4+ KB

# %%
df_audio.describe()
# Out:
#                                                      path label
# count                                                2000  2000
# unique                                               2000    10
# top     /content/drive/MyDrive/Audio_Spoken_Digit/reco...     9
# freq                                                    1   200

# %% [markdown]
# <font size=4>Grader function 2 </font>

# %%
def grader_df():
    flag_shape = df_audio.shape==(2000,2)
    flag_columns = all(df_audio.columns==['path', 'label'])
    list_values = list(df_audio.label.value_counts())
    flag_label = len(list_values)==10
    flag_label2 = all([i==200 for i in list_values])
    final_flag = flag_shape and flag_columns and flag_label and flag_label2
    return final_flag
grader_df()
# Out:
# True

# %%
from sklearn.utils import shuffle
df_audio = shuffle(df_audio, random_state=33)#don't change the random state

# %% [markdown]
# <pre><font size=4>Train and Validation split</font></pre>

# %%
#split the data into train and validation and save in X_train, X_test, y_train, y_test
#use stratify sampling
#use random state of 45
#use test size of 30%

X = df_audio['path']
Y = df_audio['label'].astype("int32")
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.3, stratify = Y, random_state = 45)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((1400,), (600,), (1400,), (600,))

# %% [markdown]
# <font size=4>Grader function 3 </font>

# %%
def grader_split():
    flag_len = (len(X_train)==1400) and (len(X_test)==600) and (len(y_train)==1400) and (len(y_test)==600)
    values_ytrain = list(y_train.value_counts())
    flag_ytrain = (len(values_ytrain)==10) and (all([i==140 for i in values_ytrain]))
    values_ytest = list(y_test.value_counts())
    flag_ytest = (len(values_ytest)==10) and (all([i==60 for i in values_ytest]))
    final_flag = flag_len and flag_ytrain and flag_ytest
    return final_flag
grader_split()
# Out:
# True

# %% [markdown]
# <pre><font size=4>Preprocessing</font>
#
# All files are in the "WAV" format. We will read those raw data files using the librosa</pre>

# %%
sample_rate = 22050
def load_wav(x, get_duration=True):
    '''This return the array values of audio with sampling rate of 22050 and Duration'''
    #loading the wav file with sampling rate of 22050
    samples, sample_rate = librosa.load(x, sr=22050)
    if get_duration:
        duration = librosa.get_duration(samples, sample_rate)
        return [samples, duration]
    else:
        return samples

# %%
# Using Parallel jobs to get the samples and duration for train and test.
a = Parallel(n_jobs=-1, verbose = 1)(delayed(load_wav)(train) for train in X_train) 
b = Parallel(n_jobs=-1, verbose = 1)(delayed(load_wav)(test) for test in X_test)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:    6.4s
# [Parallel(n_jobs=-1)]: Done 1276 tasks      | elapsed:   21.7s
# [Parallel(n_jobs=-1)]: Done 1400 out of 1400 | elapsed:   23.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 300 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=-1)]: Done 600 out of 600 | elapsed:    7.6s finished

# %%
Train_samples = []
Train_duration = []
Test_samples = []
Test_duration = []

# %%
a = np.array(a)
Train_samples = a[:,0].tolist()
Train_duration = a[:,1].tolist()
a.dtype
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   """Entry point for launching an IPython kernel.
# dtype('O')

# %%
a = np.array(a)
Train_samples = a[:,0].tolist()
Train_duration = a[:,1].tolist()

# %%
b = np.array(b)
Test_samples = b[:,0].tolist()
Test_duration = b[:,1].tolist()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   """Entry point for launching an IPython kernel.

# %%
len(Train_samples), len(Test_samples)
# Out:
# (1400, 600)

# %%
#use load_wav function that was written above to get every wave. 
#save it in X_train_processed and X_test_processed
# X_train_processed/X_test_processed should be dataframes with two columns(raw_data, duration) with same index of X_train/y_train

X_train_processed = pd.DataFrame(list(zip(Train_samples, Train_duration)), columns = ['raw_data', 'duration'])
X_test_processed = pd.DataFrame(list(zip(Test_samples, Test_duration)), columns = ['raw_data', 'duration'])
X_train_processed.shape, X_test_processed.shape
# Out:
# ((1400, 2), (600, 2))

# %%
del a
del b

# %%
# plot the histogram of the duration for train
X_train_processed['duration'].plot.hist()

# %%
# plot the histogram of the duration for test
X_test_processed['duration'].plot.hist()

# %%
#plot the histogram of the duration for trian
# Out:
# []

# %%
#plot the histogram of the duration for trian
# Out:
# (array([224., 320.,  50.,   5.,   0.,   0.,   0.,   0.,   0.,   1.]),
#  array([0.14353741, 0.35746032, 0.57138322, 0.78530612, 0.99922902,
#         1.21315193, 1.42707483, 1.64099773, 1.85492063, 2.06884354,
#         2.28276644]),
#  <a list of 10 Patch objects>)

# %%
#print 0 to 100 percentile values with step size of 10 for train data duration. 

for i in range(0, 101, 10):
    per = np.percentile(X_train_processed['duration'], i)
    print(i, 'th percentile is ', per)
# Out:
# 0 th percentile is  0.1435374149659864
# 10 th percentile is  0.2591020408163265
# 20 th percentile is  0.29586394557823126
# 30 th percentile is  0.32875283446712017
# 40 th percentile is  0.357859410430839
# 50 th percentile is  0.3873922902494331
# 60 th percentile is  0.4164172335600907
# 70 th percentile is  0.44616780045351473
# 80 th percentile is  0.48144217687074836
# 90 th percentile is  0.555297052154195
# 100 th percentile is  2.282766439909297

# %%
# Print 90 to 100 percentile values with step size of 1 for train data duration.

for i in range(90, 101):
    per = np.percentile(X_train_processed['duration'], i)
    print(i, 'th percentile is ', per)
# Out:
# 90 th percentile is  0.555297052154195
# 91 th percentile is  0.5679238095238096
# 92 th percentile is  0.5795482993197282
# 93 th percentile is  0.5941251700680278
# 94 th percentile is  0.6133478458049886
# 95 th percentile is  0.628310657596372
# 96 th percentile is  0.6431455782312925
# 97 th percentile is  0.6611179138321994
# 98 th percentile is  0.6925750566893424
# 99 th percentile is  0.784215873015873
# 100 th percentile is  2.282766439909297

# %% [markdown]
# <font size=4>Grader function 4 </font>

# %%
def grader_processed():
    flag_columns = (all(X_train_processed.columns==['raw_data', 'duration'])) and (all(X_test_processed.columns==['raw_data', 'duration']))
    flag_shape = (X_train_processed.shape ==(1400, 2)) and (X_test_processed.shape==(600,2))
    return flag_columns and flag_shape
grader_processed()
# Out:
# True

# %% [markdown]
# <b>Based on our analysis 99 percentile values are less than 0.8sec so we will limit maximum length of X_train_processed and X_test_processed to 0.8 sec. It is similar to pad_sequence for a text dataset.</b>
#
# <b>While loading the audio files, we are using sampling rate of 22050 so one sec will give array of length 22050. so, our maximum length is 0.8*22050 = 17640
# </b>
# <b>Pad with Zero if length of sequence is less than 17640 else Truncate the number. </b>
#
# <b> Also create a masking vector for train and test. </b>
#
# <b> masking vector value = 1 if it is real value, 0 if it is pad value. Masking vector data type must be bool.</b>

# %%
max_length  = 17640

# %%
## as discussed above, Pad with Zero if length of sequence is less than 17640 else Truncate the number. 
## save in the X_train_pad_seq, X_test_pad_seq
## also Create masking vector X_train_mask, X_test_mask

## all the X_train_pad_seq, X_test_pad_seq, X_train_mask, X_test_mask will be numpy arrays mask vector dtype must be bool.

# %%
X_train_mask = np.array([np.ones(g.shape[0]) for g in X_train_processed['raw_data'].values])
X_train_mask.shape
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   """Entry point for launching an IPython kernel.
# (1400,)

# %%
X_test_mask = np.array([np.ones(g.shape[0]) for g in X_test_processed['raw_data'].values])
X_test_mask.shape
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   """Entry point for launching an IPython kernel.
# (600,)

# %%
X_train_mask[-50].shape, X_train_processed['raw_data'].values[-50].shape
# Out:
# ((5612,), (5612,))

# %%
#X_train_pad_seq & X_train_mask:

X_train_pad_seq = pad_sequences(X_train_processed['raw_data'], maxlen=max_length, padding='post', dtype = np.float32, truncating='post')
X_train_mask = pad_sequences(X_train_mask, maxlen=max_length, padding='post', dtype = bool, truncating='post')

# %%
#X_test_pad_seq & X_test_mask:

X_test_pad_seq = pad_sequences(X_test_processed['raw_data'], maxlen=max_length, padding='post', dtype = np.float32, truncating='post')
X_test_mask = pad_sequences(X_test_mask, maxlen=max_length, padding='post', dtype = bool, truncating='post')

# %%
X_test_pad_seq
# Out:
# array([[-1.26367854e-02, -1.55794946e-02, -1.13195395e-02, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [-1.18654723e-04, -2.41128844e-04, -2.04156895e-04, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [-7.05007842e-05, -7.15753195e-05, -4.50172411e-05, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        ...,
#        [ 1.53095997e-03,  2.04080902e-03,  2.03249208e-03, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 7.05277140e-04,  1.56983704e-04, -3.24962894e-04, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [-2.44123731e-02, -3.74546014e-02, -4.49726209e-02, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00]], dtype=float32)

# %%
X_test_mask
# Out:
# array([[ True,  True,  True, ..., False, False, False],
#        [ True,  True,  True, ..., False, False, False],
#        [ True,  True,  True, ..., False, False, False],
#        ...,
#        [ True,  True,  True, ..., False, False, False],
#        [ True,  True,  True, ..., False, False, False],
#        [ True,  True,  True, ..., False, False, False]])

# %% [markdown]
# <font size=4>Grader function 5 </font>

# %%
def grader_padoutput():
    flag_padshape = (X_train_pad_seq.shape==(1400, 17640)) and (X_test_pad_seq.shape==(600, 17640)) and (y_train.shape==(1400,))
    flag_maskshape = (X_train_mask.shape==(1400, 17640)) and (X_test_mask.shape==(600, 17640)) and (y_test.shape==(600,))
    flag_dtype = (X_train_mask.dtype==bool) and (X_test_mask.dtype==bool)
    return flag_padshape and flag_maskshape and flag_dtype
grader_padoutput()
# Out:
# True

# %%
# Changing the dimension.
X_T_pad = tf.expand_dims(X_train_pad_seq, axis = 2)
X_T_pad.shape, X_T_pad[0].shape
# Out:
# (TensorShape([1400, 17640, 1]), TensorShape([17640, 1]))

# %%
X_Te_pad = tf.expand_dims(X_test_pad_seq, axis = 2)
X_Te_pad.shape, X_Te_pad[0].shape
# Out:
# (TensorShape([600, 17640, 1]), TensorShape([17640, 1]))

# %%
Train = [X_T_pad, X_train_mask]
Val = [X_Te_pad, X_test_mask]

# %%
Train_data = (Train, y_train.values)
Val_data = (Val, y_test.values)

# %% [markdown]
# ### 1. Giving Raw data directly.

# %% [markdown]
# Now we have
#
# Train data: X_train_pad_seq, X_train_mask and y_train
# Test data: X_test_pad_seq, X_test_mask and y_test
#
# We will create a LSTM model which takes this input.
#
# Task:
#
# 1. Create an LSTM network which takes "X_train_pad_seq" as input, "X_train_mask" as mask input. You can use any number of LSTM cells. Please read LSTM documentation(https://www.tensorflow.org/api_docs/python/tf/keras/layers/LSTM) in tensorflow to know more about mask and also https://www.tensorflow.org/guide/keras/masking_and_padding
# 2. Get the final output of the LSTM and give it to Dense layer of any size and then give it to Dense layer of size 10(because we have 10 outputs) and then compile with the sparse categorical cross entropy( because we are not converting it to one hot vectors). Also check the datatype of class labels(y_values) and make sure that you convert your class labels  to integer datatype before fitting in the model.
# 3. While defining your model make sure that you pass both the input layer and mask input layer as input to lstm layer as follows
# <img src='https://i.imgur.com/FvcgvbY.jpg'>
# 4. Use tensorboard to plot the graphs of loss and metric(use custom micro F1 score as metric) and histograms of gradients. You can write your code for computing F1 score using this <a  href='https://i.imgur.com/8YULUcu.jpg'>link</a>
#
# 5. make sure that it won't overfit.
# 6. You are free to include any regularization

# %%
from tensorflow.keras.layers import Input, LSTM, Dense
from tensorflow.keras.models import Model
import tensorflow as tf

# %%
tf.keras.backend.clear_session()
class Metrics(tf.keras.callbacks.Callback):
    
    def __init__(self, x = None, y = None):
        self.training_data = x 
        self.validation_data = y
    
    def on_train_begin(self, logs = {}):
        ## on begin of training, we are creating a instance varible called history
        self.history={'train_f1_score': [], 'val_f1_score': []}

        
    def on_epoch_end(self, epoch, logs = {}):
        ## on end of each epoch, we will get logs and update the self.history dict
        train_predict = self.model.predict(self.training_data[0], batch_size = 50)
        train_bin = np.argmax(train_predict, axis = 1)
        train_targ = self.training_data[1]
        _train_f1 = f1_score(train_targ, train_bin, average = 'micro')
       
         
        val_predict = self.model.predict(self.validation_data[0], batch_size = 50)
        val_bin = np.argmax(val_predict, axis = 1)
        val_targ = self.validation_data[1]
        _val_f1 = f1_score(val_targ, val_bin, average = 'micro')
             
        self.history['val_f1_score'].append(_val_f1)
        self.history['train_f1_score'].append(_train_f1)
        
        print(' - train_f1_score : ', _train_f1, ' - val_f1_score : ', _val_f1)
        return

# %%
def changeLearningRate(epoch):
    global initial_learningrate
    epoch = epoch + 1
    if epoch % 5 == 0:
        initial_learningrate *= 0.55
    return initial_learningrate

# %%
import os
save = 'model_save/*.hdf5'
r = glob.glob(save)
for i in r:
    os.remove(i)

# %%
filepath="model_save/model-{epoch:02d}-{val_sparse_categorical_accuracy:.4f}.hdf5"
checkpoint = ModelCheckpoint(filepath=filepath, monitor='val_sparse_categorical_accuracy',  verbose=1, save_best_only=True, mode='max')
reducelr = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.001, patience = 1, verbose = 1, mode = 'min')

lrschedule = LearningRateScheduler(changeLearningRate, verbose=1)
initial_learningrate=0.001

# %%
metrics = Metrics(Train_data, Val_data)
callbacks = [metrics, checkpoint, reducelr, lrschedule]
reg = tf.keras.regularizers.L2(l2=0.01)

# %%
## as discussed above, please write the architecture of the model.
## you will have two input layers in your model (data input layer and mask input layer)
## make sure that you have defined the data type of masking layer as bool

input_layer = Input(shape=(17640,1), name = 'input_layer')
input_mask = Input(shape=(17640,), name = 'mask_layer', dtype=bool)
ls = LSTM(units = 128, name = 'LSTM')(input_layer, mask = input_mask)
ls = BatchNormalization()(ls)
dc1 = Dense(512,activation='relu',kernel_initializer=tf.keras.initializers.he_normal(seed = 30), name = 'FC2')(ls)
dc1 = Dropout(0.35)(dc1)
out = Dense(10,activation='softmax',kernel_initializer=tf.keras.initializers.glorot_normal(seed = 30), name = 'FC3')(dc1)

# %%
model_raw1 = Model(inputs = [input_layer,input_mask], outputs = out)

# %%
model_raw1.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_layer (InputLayer)       [(None, 17640, 1)]   0           []
#
#  mask_layer (InputLayer)        [(None, 17640)]      0           []
#
#  LSTM (LSTM)                    (None, 128)          66560       ['input_layer[0][0]',
#                                                                   'mask_layer[0][0]']
#
#  batch_normalization (BatchNorm  (None, 128)         512         ['LSTM[0][0]']
#  alization)
#
#  FC2 (Dense)                    (None, 512)          66048       ['batch_normalization[0][0]']
#
#  dropout (Dropout)              (None, 512)          0           ['FC2[0][0]']
#
#  FC3 (Dense)                    (None, 10)           5130        ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 138,250
# Trainable params: 137,994
# Non-trainable params: 256
# __________________________________________________________________________________________________

# %%
model_raw1.compile(optimizer=tf.keras.optimizers.RMSprop(0.001),
              loss='sparse_categorical_crossentropy',
              metrics=['sparse_categorical_accuracy'])

# %%
#train your model
#model1.fit([X_train_pad_seq,X_train_mask],y_train_int,.........)s
model_history = model_raw1.fit(Train, y_train.values, batch_size = 40, validation_data = (Val, y_test.values), epochs = 6, verbose = 1, callbacks = callbacks)
# Out:
# Epoch 00001: LearningRateScheduler setting learning rate to 0.001.
# Epoch 1/6
# 35/35 [==============================] - ETA: 0s - loss: 2.3078 - sparse_categorical_accuracy: 0.0914  - train_f1_score :  0.09857142857142857  - val_f1_score :  0.10000000000000002
#
# Epoch 00001: val_sparse_categorical_accuracy improved from -inf to 0.10000, saving model to model_save/model-01-0.1000.hdf5
# 35/35 [==============================] - 1411s 41s/step - loss: 2.3078 - sparse_categorical_accuracy: 0.0914 - val_loss: 2.3027 - val_sparse_categorical_accuracy: 0.1000 - lr: 0.0010
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.001.
# Epoch 2/6
# 35/35 [==============================] - ETA: 0s - loss: 2.3014 - sparse_categorical_accuracy: 0.0950  - train_f1_score :  0.10142857142857142  - val_f1_score :  0.10000000000000002
#
# Epoch 00002: val_sparse_categorical_accuracy did not improve from 0.10000
#
# Epoch 00002: ReduceLROnPlateau reducing learning rate to 1.0000000474974512e-06.
# 35/35 [==============================] - 1383s 40s/step - loss: 2.3014 - sparse_categorical_accuracy: 0.0950 - val_loss: 2.3037 - val_sparse_categorical_accuracy: 0.1000 - lr: 1.0000e-06
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.001.
# Epoch 3/6
# 35/35 [==============================] - ETA: 0s - loss: 2.2984 - sparse_categorical_accuracy: 0.0971  - train_f1_score :  0.0992857142857143  - val_f1_score :  0.10000000000000002
#
# Epoch 00003: val_sparse_categorical_accuracy did not improve from 0.10000
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 1.0000000474974512e-06.
# 35/35 [==============================] - 1392s 40s/step - loss: 2.2984 - sparse_categorical_accuracy: 0.0971 - val_loss: 2.3031 - val_sparse_categorical_accuracy: 0.1000 - lr: 1.0000e-06
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.001.
# Epoch 4/6
# 35/35 [==============================] - ETA: 0s - loss: 2.5980 - sparse_categorical_accuracy: 0.0957  - train_f1_score :  0.10071428571428571  - val_f1_score :  0.10000000000000002
#
# Epoch 00004: val_sparse_categorical_accuracy did not improve from 0.10000
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 1.0000000474974512e-06.
# 35/35 [==============================] - 1381s 40s/step - loss: 2.5980 - sparse_categorical_accuracy: 0.0957 - val_loss: 2.3029 - val_sparse_categorical_accuracy: 0.1000 - lr: 1.0000e-06
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.00055.
# Epoch 5/6
# 35/35 [==============================] - ETA: 0s - loss: 2.3039 - sparse_categorical_accuracy: 0.1021  - train_f1_score :  0.09857142857142857  - val_f1_score :  0.10000000000000002
#
# Epoch 00005: val_sparse_categorical_accuracy did not improve from 0.10000
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 5.499999970197678e-07.
# 35/35 [==============================] - 1385s 40s/step - loss: 2.3039 - sparse_categorical_accuracy: 0.1021 - val_loss: 2.3028 - val_sparse_categorical_accuracy: 0.1000 - lr: 5.5000e-07
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.00055.
# Epoch 6/6
# 35/35 [==============================] - ETA: 0s - loss: 2.3002 - sparse_categorical_accuracy: 0.1143  - train_f1_score :  0.09857142857142857  - val_f1_score :  0.10000000000000002
#
# Epoch 00006: val_sparse_categorical_accuracy did not improve from 0.10000
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 5.499999970197678e-07.
# 35/35 [==============================] - 1394s 40s/step - loss: 2.3002 - sparse_categorical_accuracy: 0.1143 - val_loss: 2.3028 - val_sparse_categorical_accuracy: 0.1000 - lr: 5.5000e-07

# %%
model_raw1.save('Model_raw_1_0.1517_final.h5')

# %%
model_raw1 = load_model('/content/Model_raw_1_0.1517_final.h5')

# %%
## as discussed above, please write the LSTM
y_pred = model_raw1.predict(Val)
y_pred = np.argmax(y_pred, axis = 1)

# %%
print('Classification Report')
print(classification_report(y_test.values, y_pred))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        60
#            1       0.00      0.00      0.00        60
#            2       0.26      0.10      0.14        60
#            3       0.00      0.00      0.00        60
#            4       0.06      0.02      0.03        60
#            5       0.00      0.00      0.00        60
#            6       0.00      0.00      0.00        60
#            7       0.00      0.00      0.00        60
#            8       0.10      0.32      0.15        60
#            9       0.12      0.68      0.20        60
#
#     accuracy                           0.11       600
#    macro avg       0.05      0.11      0.05       600
# weighted avg       0.05      0.11      0.05       600
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
ax= plt.subplot()
sns.heatmap(confusion_matrix(y_test.values, y_pred), annot=True, ax = ax, fmt='g', cmap='Greens') #annot=True to annotate cells

ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels') 
ax.set_title('Confusion Matrix')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
plot_model(model_raw1, show_shapes=True, show_layer_names=True)

# %% [markdown]
# ### 2. Converting into spectrogram and giving spectrogram data as input
#
# We can use librosa to convert raw data into spectrogram. A spectrogram shows the features in a two-dimensional representation with the
# intensity of a frequency at a point in time i.e we are converting Time domain to frequency domain. you can read more about this in https://pnsn.org/spectrograms/what-is-a-spectrogram

# %%
def convert_to_spectrogram(raw_data):
    '''converting to spectrogram'''
    spectrum = librosa.feature.melspectrogram(y=raw_data, sr=sample_rate, n_mels=64)
    logmel_spectrum = librosa.power_to_db(S=spectrum, ref=np.max)
    return logmel_spectrum

# %%
###use convert_to_spectrogram and convert every raw sequence in X_train_pad_seq and X_test_pad-seq.
## save those all in the X_train_spectrogram and X_test_spectrogram ( These two arrays must be numpy arrays)
#X_train_spectrogram:
X_train_spectrogram = []
for j in X_train_pad_seq:
    l = convert_to_spectrogram(j)
    X_train_spectrogram.append(l)
X_train_spectrogram = np.array(X_train_spectrogram)

# %%
#X_test_spectrogram:
X_test_spectrogram = []
for j in X_test_pad_seq:
    l = convert_to_spectrogram(j)
    X_test_spectrogram.append(l)
X_test_spectrogram = np.array(X_test_spectrogram)

# %%
plt.subplots_adjust(wspace=1, hspace=1)
for i in range(0,3):
    fig, ax = plt.subplots()
    img = librosa.display.specshow(convert_to_spectrogram(X_train_processed['raw_data'][i]), y_axis='mel', x_axis='time', ax=ax)
    ax.set(title='Mel spectrogram display')
    ax.set_ylim([0,6000])
    fig.colorbar(img, ax=ax, format="%+2.f dB")

# %% [markdown]
# <font size=4>Grader function 6 </font>

# %%
def grader_spectrogram():
    flag_shape = (X_train_spectrogram.shape==(1400,64, 35)) and (X_test_spectrogram.shape == (600, 64, 35))
    return flag_shape
grader_spectrogram()
# Out:
# True

# %% [markdown]
# Now we have
#
# Train data: X_train_spectrogram and y_train
# Test data: X_test_spectrogram and y_test
#
# We will create a LSTM model which takes this input.
#
# Task:
#
# 1. Create an LSTM network which takes "X_train_spectrogram" as input and has to return output at every time step.
# 2. Average the output of every time step and give this to the Dense layer of any size.
# (ex: Output from LSTM will be  (None, time_steps, features) average the output of every time step i.e, you should get (None,time_steps)
# and then pass to dense layer )
# 3. give the above output to Dense layer of size 10( output layer) and train the network with sparse categorical cross entropy.
# 4. Use tensorboard to plot the graphs of loss and metric(use custom micro F1 score as metric) and histograms of gradients. You can write your code for computing F1 score using this <a  href='https://i.imgur.com/8YULUcu.jpg'>link</a>
# 5. make sure that it won't overfit.
# 6. You are free to include any regularization

# %%
tf.keras.backend.clear_session()
reg = tf.keras.regularizers.L2(l2=1.5)

# %%
# write the architecture of the model
#print model.summary and make sure that it is following point 2 mentioned above
tf.keras.backend.clear_session()
input_layer = Input(shape=(64,35), name = 'input_layer')
ls = LSTM(units = 128, name = 'LSTM', return_sequences = True)(input_layer)
ad = GlobalAveragePooling1D()(ls)
dc1 = Dense(1024,activation='relu',kernel_initializer=tf.keras.initializers.he_normal(seed = 30), name = 'FC1')(ad)
dc1 = Dense(256,activation='relu',kernel_initializer=tf.keras.initializers.he_normal(seed = 30), name = 'FC2')(dc1)
dc1 = BatchNormalization()(dc1)
dc1 = Dropout(0.6899)(dc1)
out = Dense(10,activation='softmax',kernel_initializer=tf.keras.initializers.glorot_normal(seed = 30), name = 'FC3')(dc1)

# %%
m_spec = Model(inputs = input_layer, outputs = out)

# %%
m_spec.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 64, 35)]          0
#
#  LSTM (LSTM)                 (None, 64, 128)           83968
#
#  global_average_pooling1d (G  (None, 128)              0
#  lobalAveragePooling1D)
#
#  FC1 (Dense)                 (None, 1024)              132096
#
#  FC2 (Dense)                 (None, 256)               262400
#
#  batch_normalization (BatchN  (None, 256)              1024
#  ormalization)
#
#  dropout (Dropout)           (None, 256)               0
#
#  FC3 (Dense)                 (None, 10)                2570
#
# =================================================================
# Total params: 482,058
# Trainable params: 481,546
# Non-trainable params: 512
# _________________________________________________________________

# %%
save = 'model_spec_save/*.hdf5'
r = glob.glob(save)
for i in r:
    os.remove(i)

# %%
filepath="model_spec_save/model-{epoch:02d}-{val_sparse_categorical_accuracy:.4f}.hdf5"
checkpoint = ModelCheckpoint(filepath=filepath, monitor='val_sparse_categorical_accuracy',  verbose=1, save_best_only=True, mode='max')
reducelr = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.055, patience = 1, verbose = 1, mode = 'min')

lrschedule = LearningRateScheduler(changeLearningRate, verbose=1)
initial_learningrate=0.001

# %%
Train_data_spec = [X_train_spectrogram, y_train.values]
Test_data_spec = [X_test_spectrogram, y_test.values]
metrics = Metrics(Train_data_spec, Test_data_spec)
callbacks = [metrics, checkpoint, reducelr, lrschedule]

# %%
#compile and fit your model.
#model2.fit([X_train_spectrogram],y_train_int,......)
m_spec.compile(optimizer=tf.keras.optimizers.Adam(0.001),
              loss='sparse_categorical_crossentropy',
               
              metrics=['sparse_categorical_accuracy'])

# %%
tf.keras.backend.clear_session()
model_spec_history = m_spec.fit(X_train_spectrogram, y_train.values, batch_size =50, validation_data = (X_test_spectrogram, y_test.values), epochs=50, verbose=1, callbacks=callbacks)
# Out:
# Epoch 00001: LearningRateScheduler setting learning rate to 0.001.
# Epoch 1/50
# 28/28 [==============================] - ETA: 0s - loss: 2.5783 - sparse_categorical_accuracy: 0.2593 - train_f1_score :  0.18714285714285714  - val_f1_score :  0.18
#
# Epoch 00001: val_sparse_categorical_accuracy improved from -inf to 0.18000, saving model to model_spec_save/model-01-0.1800.hdf5
# 28/28 [==============================] - 8s 226ms/step - loss: 2.5783 - sparse_categorical_accuracy: 0.2593 - val_loss: 2.5539 - val_sparse_categorical_accuracy: 0.1800 - lr: 0.0010
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.001.
# Epoch 2/50
# 28/28 [==============================] - ETA: 0s - loss: 2.0756 - sparse_categorical_accuracy: 0.3307 - train_f1_score :  0.14714285714285713  - val_f1_score :  0.15333333333333332
#
# Epoch 00002: val_sparse_categorical_accuracy did not improve from 0.18000
#
# Epoch 00002: ReduceLROnPlateau reducing learning rate to 5.500000261235982e-05.
# 28/28 [==============================] - 6s 206ms/step - loss: 2.0756 - sparse_categorical_accuracy: 0.3307 - val_loss: 2.7140 - val_sparse_categorical_accuracy: 0.1533 - lr: 5.5000e-05
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.001.
# Epoch 3/50
# 28/28 [==============================] - ETA: 0s - loss: 1.8361 - sparse_categorical_accuracy: 0.3893 - train_f1_score :  0.1392857142857143  - val_f1_score :  0.13666666666666666
#
# Epoch 00003: val_sparse_categorical_accuracy did not improve from 0.18000
# 28/28 [==============================] - 5s 187ms/step - loss: 1.8361 - sparse_categorical_accuracy: 0.3893 - val_loss: 2.4899 - val_sparse_categorical_accuracy: 0.1367 - lr: 0.0010
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.001.
# Epoch 4/50
# 28/28 [==============================] - ETA: 0s - loss: 1.6780 - sparse_categorical_accuracy: 0.4443 - train_f1_score :  0.15285714285714286  - val_f1_score :  0.14333333333333334
#
# Epoch 00004: val_sparse_categorical_accuracy did not improve from 0.18000
# 28/28 [==============================] - 5s 188ms/step - loss: 1.6780 - sparse_categorical_accuracy: 0.4443 - val_loss: 2.3966 - val_sparse_categorical_accuracy: 0.1433 - lr: 0.0010
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.00055.
# Epoch 5/50
# 28/28 [==============================] - ETA: 0s - loss: 1.5324 - sparse_categorical_accuracy: 0.4686 - train_f1_score :  0.20857142857142857  - val_f1_score :  0.22666666666666666
#
# Epoch 00005: val_sparse_categorical_accuracy improved from 0.18000 to 0.22667, saving model to model_spec_save/model-05-0.2267.hdf5
# 28/28 [==============================] - 5s 188ms/step - loss: 1.5324 - sparse_categorical_accuracy: 0.4686 - val_loss: 2.1626 - val_sparse_categorical_accuracy: 0.2267 - lr: 5.5000e-04
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.00055.
# Epoch 6/50
# 28/28 [==============================] - ETA: 0s - loss: 1.4018 - sparse_categorical_accuracy: 0.5043 - train_f1_score :  0.25642857142857145  - val_f1_score :  0.25666666666666665
#
# Epoch 00006: val_sparse_categorical_accuracy improved from 0.22667 to 0.25667, saving model to model_spec_save/model-06-0.2567.hdf5
# 28/28 [==============================] - 5s 192ms/step - loss: 1.4018 - sparse_categorical_accuracy: 0.5043 - val_loss: 2.0198 - val_sparse_categorical_accuracy: 0.2567 - lr: 5.5000e-04
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.00055.
# Epoch 7/50
# 28/28 [==============================] - ETA: 0s - loss: 1.3149 - sparse_categorical_accuracy: 0.5429 - train_f1_score :  0.2407142857142857  - val_f1_score :  0.23
#
# Epoch 00007: val_sparse_categorical_accuracy did not improve from 0.25667
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 3.0249999836087226e-05.
# 28/28 [==============================] - 5s 186ms/step - loss: 1.3149 - sparse_categorical_accuracy: 0.5429 - val_loss: 2.1163 - val_sparse_categorical_accuracy: 0.2300 - lr: 3.0250e-05
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.00055.
# Epoch 8/50
# 28/28 [==============================] - ETA: 0s - loss: 1.2651 - sparse_categorical_accuracy: 0.5586 - train_f1_score :  0.32857142857142857  - val_f1_score :  0.315
#
# Epoch 00008: val_sparse_categorical_accuracy improved from 0.25667 to 0.31500, saving model to model_spec_save/model-08-0.3150.hdf5
# 28/28 [==============================] - 5s 192ms/step - loss: 1.2651 - sparse_categorical_accuracy: 0.5586 - val_loss: 1.8568 - val_sparse_categorical_accuracy: 0.3150 - lr: 5.5000e-04
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.00055.
# Epoch 9/50
# 28/28 [==============================] - ETA: 0s - loss: 1.1771 - sparse_categorical_accuracy: 0.5714 - train_f1_score :  0.37142857142857144  - val_f1_score :  0.3633333333333333
#
# Epoch 00009: val_sparse_categorical_accuracy improved from 0.31500 to 0.36333, saving model to model_spec_save/model-09-0.3633.hdf5
# 28/28 [==============================] - 5s 189ms/step - loss: 1.1771 - sparse_categorical_accuracy: 0.5714 - val_loss: 1.7712 - val_sparse_categorical_accuracy: 0.3633 - lr: 5.5000e-04
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.00030250000000000003.
# Epoch 10/50
# 28/28 [==============================] - ETA: 0s - loss: 1.1541 - sparse_categorical_accuracy: 0.5964 - train_f1_score :  0.44571428571428573  - val_f1_score :  0.4533333333333333
#
# Epoch 00010: val_sparse_categorical_accuracy improved from 0.36333 to 0.45333, saving model to model_spec_save/model-10-0.4533.hdf5
# 28/28 [==============================] - 5s 189ms/step - loss: 1.1541 - sparse_categorical_accuracy: 0.5964 - val_loss: 1.5563 - val_sparse_categorical_accuracy: 0.4533 - lr: 3.0250e-04
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.00030250000000000003.
# Epoch 11/50
# 28/28 [==============================] - ETA: 0s - loss: 1.0596 - sparse_categorical_accuracy: 0.6279 - train_f1_score :  0.535  - val_f1_score :  0.5216666666666666
#
# Epoch 00011: val_sparse_categorical_accuracy improved from 0.45333 to 0.52167, saving model to model_spec_save/model-11-0.5217.hdf5
# 28/28 [==============================] - 5s 190ms/step - loss: 1.0596 - sparse_categorical_accuracy: 0.6279 - val_loss: 1.3874 - val_sparse_categorical_accuracy: 0.5217 - lr: 3.0250e-04
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.00030250000000000003.
# Epoch 12/50
# 28/28 [==============================] - ETA: 0s - loss: 1.0403 - sparse_categorical_accuracy: 0.6421 - train_f1_score :  0.5764285714285714  - val_f1_score :  0.545
#
# Epoch 00012: val_sparse_categorical_accuracy improved from 0.52167 to 0.54500, saving model to model_spec_save/model-12-0.5450.hdf5
# 28/28 [==============================] - 5s 192ms/step - loss: 1.0403 - sparse_categorical_accuracy: 0.6421 - val_loss: 1.3238 - val_sparse_categorical_accuracy: 0.5450 - lr: 3.0250e-04
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.00030250000000000003.
# Epoch 13/50
# 28/28 [==============================] - ETA: 0s - loss: 1.0326 - sparse_categorical_accuracy: 0.6293 - train_f1_score :  0.605  - val_f1_score :  0.5783333333333334
#
# Epoch 00013: val_sparse_categorical_accuracy improved from 0.54500 to 0.57833, saving model to model_spec_save/model-13-0.5783.hdf5
# 28/28 [==============================] - 5s 196ms/step - loss: 1.0326 - sparse_categorical_accuracy: 0.6293 - val_loss: 1.2517 - val_sparse_categorical_accuracy: 0.5783 - lr: 3.0250e-04
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.00030250000000000003.
# Epoch 14/50
# 28/28 [==============================] - ETA: 0s - loss: 1.0030 - sparse_categorical_accuracy: 0.6336 - train_f1_score :  0.5685714285714286  - val_f1_score :  0.5416666666666666
#
# Epoch 00014: val_sparse_categorical_accuracy did not improve from 0.57833
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 1.663750022999011e-05.
# 28/28 [==============================] - 5s 193ms/step - loss: 1.0030 - sparse_categorical_accuracy: 0.6336 - val_loss: 1.3024 - val_sparse_categorical_accuracy: 0.5417 - lr: 1.6637e-05
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.00016637500000000002.
# Epoch 15/50
# 28/28 [==============================] - ETA: 0s - loss: 0.9254 - sparse_categorical_accuracy: 0.6743 - train_f1_score :  0.7064285714285714  - val_f1_score :  0.67
#
# Epoch 00015: val_sparse_categorical_accuracy improved from 0.57833 to 0.67000, saving model to model_spec_save/model-15-0.6700.hdf5
# 28/28 [==============================] - 5s 195ms/step - loss: 0.9254 - sparse_categorical_accuracy: 0.6743 - val_loss: 1.0565 - val_sparse_categorical_accuracy: 0.6700 - lr: 1.6638e-04
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.00016637500000000002.
# Epoch 16/50
# 28/28 [==============================] - ETA: 0s - loss: 0.9259 - sparse_categorical_accuracy: 0.6757 - train_f1_score :  0.6992857142857143  - val_f1_score :  0.6616666666666666
#
# Epoch 00016: val_sparse_categorical_accuracy did not improve from 0.67000
# 28/28 [==============================] - 5s 191ms/step - loss: 0.9259 - sparse_categorical_accuracy: 0.6757 - val_loss: 1.0165 - val_sparse_categorical_accuracy: 0.6617 - lr: 1.6638e-04
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.00016637500000000002.
# Epoch 17/50
# 28/28 [==============================] - ETA: 0s - loss: 0.9424 - sparse_categorical_accuracy: 0.6686 - train_f1_score :  0.7299999999999999  - val_f1_score :  0.6866666666666666
#
# Epoch 00017: val_sparse_categorical_accuracy improved from 0.67000 to 0.68667, saving model to model_spec_save/model-17-0.6867.hdf5
# 28/28 [==============================] - 5s 190ms/step - loss: 0.9424 - sparse_categorical_accuracy: 0.6686 - val_loss: 0.9769 - val_sparse_categorical_accuracy: 0.6867 - lr: 1.6638e-04
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.00016637500000000002.
# Epoch 18/50
# 28/28 [==============================] - ETA: 0s - loss: 0.8889 - sparse_categorical_accuracy: 0.6871 - train_f1_score :  0.7028571428571428  - val_f1_score :  0.675
#
# Epoch 00018: val_sparse_categorical_accuracy did not improve from 0.68667
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 9.150625046459027e-06.
# 28/28 [==============================] - 5s 187ms/step - loss: 0.8889 - sparse_categorical_accuracy: 0.6871 - val_loss: 0.9887 - val_sparse_categorical_accuracy: 0.6750 - lr: 9.1506e-06
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.00016637500000000002.
# Epoch 19/50
# 28/28 [==============================] - ETA: 0s - loss: 0.8983 - sparse_categorical_accuracy: 0.6829 - train_f1_score :  0.705  - val_f1_score :  0.67
#
# Epoch 00019: val_sparse_categorical_accuracy did not improve from 0.68667
# 28/28 [==============================] - 5s 189ms/step - loss: 0.8983 - sparse_categorical_accuracy: 0.6829 - val_loss: 0.9757 - val_sparse_categorical_accuracy: 0.6700 - lr: 1.6638e-04
#
# Epoch 00020: LearningRateScheduler setting learning rate to 9.150625000000002e-05.
# Epoch 20/50
# 28/28 [==============================] - ETA: 0s - loss: 0.8945 - sparse_categorical_accuracy: 0.6850 - train_f1_score :  0.7299999999999999  - val_f1_score :  0.6816666666666666
#
# Epoch 00020: val_sparse_categorical_accuracy did not improve from 0.68667
# 28/28 [==============================] - 5s 185ms/step - loss: 0.8945 - sparse_categorical_accuracy: 0.6850 - val_loss: 0.9102 - val_sparse_categorical_accuracy: 0.6817 - lr: 9.1506e-05
#
# Epoch 00021: LearningRateScheduler setting learning rate to 9.150625000000002e-05.
# Epoch 21/50
# 28/28 [==============================] - ETA: 0s - loss: 0.8693 - sparse_categorical_accuracy: 0.7007 - train_f1_score :  0.7678571428571429  - val_f1_score :  0.7366666666666667
#
# Epoch 00021: val_sparse_categorical_accuracy improved from 0.68667 to 0.73667, saving model to model_spec_save/model-21-0.7367.hdf5
# 28/28 [==============================] - 5s 188ms/step - loss: 0.8693 - sparse_categorical_accuracy: 0.7007 - val_loss: 0.8289 - val_sparse_categorical_accuracy: 0.7367 - lr: 9.1506e-05
#
# Epoch 00022: LearningRateScheduler setting learning rate to 9.150625000000002e-05.
# Epoch 22/50
# 28/28 [==============================] - ETA: 0s - loss: 0.8470 - sparse_categorical_accuracy: 0.7107 - train_f1_score :  0.7571428571428571  - val_f1_score :  0.7266666666666666
#
# Epoch 00022: val_sparse_categorical_accuracy did not improve from 0.73667
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 5.032843655499164e-06.
# 28/28 [==============================] - 5s 189ms/step - loss: 0.8470 - sparse_categorical_accuracy: 0.7107 - val_loss: 0.8455 - val_sparse_categorical_accuracy: 0.7267 - lr: 5.0328e-06
#
# Epoch 00023: LearningRateScheduler setting learning rate to 9.150625000000002e-05.
# Epoch 23/50
# 28/28 [==============================] - ETA: 0s - loss: 0.8221 - sparse_categorical_accuracy: 0.7107 - train_f1_score :  0.7578571428571429  - val_f1_score :  0.7266666666666666
#
# Epoch 00023: val_sparse_categorical_accuracy did not improve from 0.73667
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 5.032843655499164e-06.
# 28/28 [==============================] - 5s 187ms/step - loss: 0.8221 - sparse_categorical_accuracy: 0.7107 - val_loss: 0.8484 - val_sparse_categorical_accuracy: 0.7267 - lr: 5.0328e-06
#
# Epoch 00024: LearningRateScheduler setting learning rate to 9.150625000000002e-05.
# Epoch 24/50
# 28/28 [==============================] - ETA: 0s - loss: 0.8356 - sparse_categorical_accuracy: 0.7086 - train_f1_score :  0.7764285714285715  - val_f1_score :  0.7333333333333333
#
# Epoch 00024: val_sparse_categorical_accuracy did not improve from 0.73667
# 28/28 [==============================] - 5s 193ms/step - loss: 0.8356 - sparse_categorical_accuracy: 0.7086 - val_loss: 0.7984 - val_sparse_categorical_accuracy: 0.7333 - lr: 9.1506e-05
#
# Epoch 00025: LearningRateScheduler setting learning rate to 5.032843750000002e-05.
# Epoch 25/50
# 28/28 [==============================] - ETA: 0s - loss: 0.8054 - sparse_categorical_accuracy: 0.7236 - train_f1_score :  0.787142857142857  - val_f1_score :  0.7433333333333333
#
# Epoch 00025: val_sparse_categorical_accuracy improved from 0.73667 to 0.74333, saving model to model_spec_save/model-25-0.7433.hdf5
# 28/28 [==============================] - 5s 190ms/step - loss: 0.8054 - sparse_categorical_accuracy: 0.7236 - val_loss: 0.7964 - val_sparse_categorical_accuracy: 0.7433 - lr: 5.0328e-05
#
# Epoch 00026: LearningRateScheduler setting learning rate to 5.032843750000002e-05.
# Epoch 26/50
# 28/28 [==============================] - ETA: 0s - loss: 0.7886 - sparse_categorical_accuracy: 0.7264 - train_f1_score :  0.7771428571428571  - val_f1_score :  0.7433333333333333
#
# Epoch 00026: val_sparse_categorical_accuracy did not improve from 0.74333
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 2.7680641505867245e-06.
# 28/28 [==============================] - 5s 188ms/step - loss: 0.7886 - sparse_categorical_accuracy: 0.7264 - val_loss: 0.8118 - val_sparse_categorical_accuracy: 0.7433 - lr: 2.7681e-06
#
# Epoch 00027: LearningRateScheduler setting learning rate to 5.032843750000002e-05.
# Epoch 27/50
# 28/28 [==============================] - ETA: 0s - loss: 0.8009 - sparse_categorical_accuracy: 0.7129 - train_f1_score :  0.7907142857142857  - val_f1_score :  0.745
#
# Epoch 00027: val_sparse_categorical_accuracy improved from 0.74333 to 0.74500, saving model to model_spec_save/model-27-0.7450.hdf5
# 28/28 [==============================] - 5s 191ms/step - loss: 0.8009 - sparse_categorical_accuracy: 0.7129 - val_loss: 0.7770 - val_sparse_categorical_accuracy: 0.7450 - lr: 5.0328e-05
#
# Epoch 00028: LearningRateScheduler setting learning rate to 5.032843750000002e-05.
# Epoch 28/50
# 28/28 [==============================] - ETA: 0s - loss: 0.7907 - sparse_categorical_accuracy: 0.7207 - train_f1_score :  0.7885714285714286  - val_f1_score :  0.745
#
# Epoch 00028: val_sparse_categorical_accuracy did not improve from 0.74500
# 28/28 [==============================] - 5s 188ms/step - loss: 0.7907 - sparse_categorical_accuracy: 0.7207 - val_loss: 0.7717 - val_sparse_categorical_accuracy: 0.7450 - lr: 5.0328e-05
#
# Epoch 00029: LearningRateScheduler setting learning rate to 5.032843750000002e-05.
# Epoch 29/50
# 28/28 [==============================] - ETA: 0s - loss: 0.7997 - sparse_categorical_accuracy: 0.7129 - train_f1_score :  0.79  - val_f1_score :  0.7433333333333333
#
# Epoch 00029: val_sparse_categorical_accuracy did not improve from 0.74500
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 2.7680641505867245e-06.
# 28/28 [==============================] - 5s 185ms/step - loss: 0.7997 - sparse_categorical_accuracy: 0.7129 - val_loss: 0.7749 - val_sparse_categorical_accuracy: 0.7433 - lr: 2.7681e-06
#
# Epoch 00030: LearningRateScheduler setting learning rate to 2.768064062500001e-05.
# Epoch 30/50
# 28/28 [==============================] - ETA: 0s - loss: 0.7564 - sparse_categorical_accuracy: 0.7414 - train_f1_score :  0.8000000000000002  - val_f1_score :  0.75
#
# Epoch 00030: val_sparse_categorical_accuracy improved from 0.74500 to 0.75000, saving model to model_spec_save/model-30-0.7500.hdf5
# 28/28 [==============================] - 5s 188ms/step - loss: 0.7564 - sparse_categorical_accuracy: 0.7414 - val_loss: 0.7611 - val_sparse_categorical_accuracy: 0.7500 - lr: 2.7681e-05
#
# Epoch 00031: LearningRateScheduler setting learning rate to 2.768064062500001e-05.
# Epoch 31/50
# 28/28 [==============================] - ETA: 0s - loss: 0.7579 - sparse_categorical_accuracy: 0.7229 - train_f1_score :  0.8000000000000002  - val_f1_score :  0.7533333333333333
#
# Epoch 00031: val_sparse_categorical_accuracy improved from 0.75000 to 0.75333, saving model to model_spec_save/model-31-0.7533.hdf5
# 28/28 [==============================] - 5s 191ms/step - loss: 0.7579 - sparse_categorical_accuracy: 0.7229 - val_loss: 0.7549 - val_sparse_categorical_accuracy: 0.7533 - lr: 2.7681e-05
#
# Epoch 00032: LearningRateScheduler setting learning rate to 2.768064062500001e-05.
# Epoch 32/50
# 28/28 [==============================] - ETA: 0s - loss: 0.7292 - sparse_categorical_accuracy: 0.7564 - train_f1_score :  0.8028571428571428  - val_f1_score :  0.75
#
# Epoch 00032: val_sparse_categorical_accuracy did not improve from 0.75333
# 28/28 [==============================] - 5s 188ms/step - loss: 0.7292 - sparse_categorical_accuracy: 0.7564 - val_loss: 0.7496 - val_sparse_categorical_accuracy: 0.7500 - lr: 2.7681e-05
#
# Epoch 00033: LearningRateScheduler setting learning rate to 2.768064062500001e-05.
# Epoch 33/50
# 28/28 [==============================] - ETA: 0s - loss: 0.7586 - sparse_categorical_accuracy: 0.7336 - train_f1_score :  0.8028571428571428  - val_f1_score :  0.7516666666666667
#
# Epoch 00033: val_sparse_categorical_accuracy did not improve from 0.75333
# 28/28 [==============================] - 5s 189ms/step - loss: 0.7586 - sparse_categorical_accuracy: 0.7336 - val_loss: 0.7402 - val_sparse_categorical_accuracy: 0.7517 - lr: 2.7681e-05
#
# Epoch 00034: LearningRateScheduler setting learning rate to 2.768064062500001e-05.
# Epoch 34/50
# 28/28 [==============================] - ETA: 0s - loss: 0.7693 - sparse_categorical_accuracy: 0.7414 - train_f1_score :  0.8035714285714286  - val_f1_score :  0.755
#
# Epoch 00034: val_sparse_categorical_accuracy improved from 0.75333 to 0.75500, saving model to model_spec_save/model-34-0.7550.hdf5
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 1.522435222796048e-06.
# 28/28 [==============================] - 5s 189ms/step - loss: 0.7693 - sparse_categorical_accuracy: 0.7414 - val_loss: 0.7469 - val_sparse_categorical_accuracy: 0.7550 - lr: 1.5224e-06
#
# Epoch 00035: LearningRateScheduler setting learning rate to 1.5224352343750007e-05.
# Epoch 35/50
# 28/28 [==============================] - ETA: 0s - loss: 0.7560 - sparse_categorical_accuracy: 0.7364 - train_f1_score :  0.8092857142857144  - val_f1_score :  0.7466666666666667
#
# Epoch 00035: val_sparse_categorical_accuracy did not improve from 0.75500
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 8.373393575311638e-07.
# 28/28 [==============================] - 5s 189ms/step - loss: 0.7560 - sparse_categorical_accuracy: 0.7364 - val_loss: 0.7465 - val_sparse_categorical_accuracy: 0.7467 - lr: 8.3734e-07
#
# Epoch 00036: LearningRateScheduler setting learning rate to 1.5224352343750007e-05.
# Epoch 36/50
# 28/28 [==============================] - ETA: 0s - loss: 0.7592 - sparse_categorical_accuracy: 0.7336 - train_f1_score :  0.8078571428571428  - val_f1_score :  0.755
#
# Epoch 00036: val_sparse_categorical_accuracy did not improve from 0.75500
# 28/28 [==============================] - 5s 187ms/step - loss: 0.7592 - sparse_categorical_accuracy: 0.7336 - val_loss: 0.7397 - val_sparse_categorical_accuracy: 0.7550 - lr: 1.5224e-05
#
# Epoch 00037: LearningRateScheduler setting learning rate to 1.5224352343750007e-05.
# Epoch 37/50
# 28/28 [==============================] - ETA: 0s - loss: 0.7460 - sparse_categorical_accuracy: 0.7350 - train_f1_score :  0.8035714285714286  - val_f1_score :  0.7516666666666667
#
# Epoch 00037: val_sparse_categorical_accuracy did not improve from 0.75500
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 8.373393575311638e-07.
# 28/28 [==============================] - 5s 187ms/step - loss: 0.7460 - sparse_categorical_accuracy: 0.7350 - val_loss: 0.7405 - val_sparse_categorical_accuracy: 0.7517 - lr: 8.3734e-07
#
# Epoch 00038: LearningRateScheduler setting learning rate to 1.5224352343750007e-05.
# Epoch 38/50
# 28/28 [==============================] - ETA: 0s - loss: 0.7484 - sparse_categorical_accuracy: 0.7379 - train_f1_score :  0.8078571428571428  - val_f1_score :  0.7583333333333333
#
# Epoch 00038: val_sparse_categorical_accuracy improved from 0.75500 to 0.75833, saving model to model_spec_save/model-38-0.7583.hdf5
# 28/28 [==============================] - 5s 189ms/step - loss: 0.7484 - sparse_categorical_accuracy: 0.7379 - val_loss: 0.7382 - val_sparse_categorical_accuracy: 0.7583 - lr: 1.5224e-05
#
# Epoch 00039: LearningRateScheduler setting learning rate to 1.5224352343750007e-05.
# Epoch 39/50
# 28/28 [==============================] - ETA: 0s - loss: 0.7641 - sparse_categorical_accuracy: 0.7393 - train_f1_score :  0.8064285714285714  - val_f1_score :  0.7666666666666667
#
# Epoch 00039: val_sparse_categorical_accuracy improved from 0.75833 to 0.76667, saving model to model_spec_save/model-39-0.7667.hdf5
# 28/28 [==============================] - 5s 189ms/step - loss: 0.7641 - sparse_categorical_accuracy: 0.7393 - val_loss: 0.7327 - val_sparse_categorical_accuracy: 0.7667 - lr: 1.5224e-05
#
# Epoch 00040: LearningRateScheduler setting learning rate to 8.373393789062505e-06.
# Epoch 40/50
# 28/28 [==============================] - ETA: 0s - loss: 0.7265 - sparse_categorical_accuracy: 0.7407 - train_f1_score :  0.8064285714285714  - val_f1_score :  0.7633333333333333
#
# Epoch 00040: val_sparse_categorical_accuracy did not improve from 0.76667
# 28/28 [==============================] - 5s 186ms/step - loss: 0.7265 - sparse_categorical_accuracy: 0.7407 - val_loss: 0.7316 - val_sparse_categorical_accuracy: 0.7633 - lr: 8.3734e-06
#
# Epoch 00041: LearningRateScheduler setting learning rate to 8.373393789062505e-06.
# Epoch 41/50
# 28/28 [==============================] - ETA: 0s - loss: 0.7412 - sparse_categorical_accuracy: 0.7336 - train_f1_score :  0.8107142857142857  - val_f1_score :  0.7633333333333333
#
# Epoch 00041: val_sparse_categorical_accuracy did not improve from 0.76667
# 28/28 [==============================] - 5s 189ms/step - loss: 0.7412 - sparse_categorical_accuracy: 0.7336 - val_loss: 0.7286 - val_sparse_categorical_accuracy: 0.7633 - lr: 8.3734e-06
#
# Epoch 00042: LearningRateScheduler setting learning rate to 8.373393789062505e-06.
# Epoch 42/50
# 28/28 [==============================] - ETA: 0s - loss: 0.7574 - sparse_categorical_accuracy: 0.7379 - train_f1_score :  0.8128571428571428  - val_f1_score :  0.7666666666666667
#
# Epoch 00042: val_sparse_categorical_accuracy did not improve from 0.76667
# 28/28 [==============================] - 5s 187ms/step - loss: 0.7574 - sparse_categorical_accuracy: 0.7379 - val_loss: 0.7284 - val_sparse_categorical_accuracy: 0.7667 - lr: 8.3734e-06
#
# Epoch 00043: LearningRateScheduler setting learning rate to 8.373393789062505e-06.
# Epoch 43/50
# 28/28 [==============================] - ETA: 0s - loss: 0.7725 - sparse_categorical_accuracy: 0.7336 - train_f1_score :  0.8114285714285714  - val_f1_score :  0.76
#
# Epoch 00043: val_sparse_categorical_accuracy did not improve from 0.76667
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 4.6053666665102354e-07.
# 28/28 [==============================] - 5s 190ms/step - loss: 0.7725 - sparse_categorical_accuracy: 0.7336 - val_loss: 0.7307 - val_sparse_categorical_accuracy: 0.7600 - lr: 4.6054e-07
#
# Epoch 00044: LearningRateScheduler setting learning rate to 8.373393789062505e-06.
# Epoch 44/50
# 28/28 [==============================] - ETA: 0s - loss: 0.7072 - sparse_categorical_accuracy: 0.7650 - train_f1_score :  0.8114285714285714  - val_f1_score :  0.7616666666666667
#
# Epoch 00044: val_sparse_categorical_accuracy did not improve from 0.76667
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 4.6053666665102354e-07.
# 28/28 [==============================] - 5s 190ms/step - loss: 0.7072 - sparse_categorical_accuracy: 0.7650 - val_loss: 0.7294 - val_sparse_categorical_accuracy: 0.7617 - lr: 4.6054e-07
#
# Epoch 00045: LearningRateScheduler setting learning rate to 4.605366583984378e-06.
# Epoch 45/50
# 28/28 [==============================] - ETA: 0s - loss: 0.7517 - sparse_categorical_accuracy: 0.7364 - train_f1_score :  0.8121428571428572  - val_f1_score :  0.7633333333333333
#
# Epoch 00045: val_sparse_categorical_accuracy did not improve from 0.76667
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 2.5329515665362126e-07.
# 28/28 [==============================] - 5s 191ms/step - loss: 0.7517 - sparse_categorical_accuracy: 0.7364 - val_loss: 0.7285 - val_sparse_categorical_accuracy: 0.7633 - lr: 2.5330e-07
#
# Epoch 00046: LearningRateScheduler setting learning rate to 4.605366583984378e-06.
# Epoch 46/50
# 28/28 [==============================] - ETA: 0s - loss: 0.7474 - sparse_categorical_accuracy: 0.7429 - train_f1_score :  0.8135714285714286  - val_f1_score :  0.7633333333333333
#
# Epoch 00046: val_sparse_categorical_accuracy did not improve from 0.76667
# 28/28 [==============================] - 5s 190ms/step - loss: 0.7474 - sparse_categorical_accuracy: 0.7429 - val_loss: 0.7276 - val_sparse_categorical_accuracy: 0.7633 - lr: 4.6054e-06
#
# Epoch 00047: LearningRateScheduler setting learning rate to 4.605366583984378e-06.
# Epoch 47/50
# 28/28 [==============================] - ETA: 0s - loss: 0.7237 - sparse_categorical_accuracy: 0.7350 - train_f1_score :  0.8157142857142857  - val_f1_score :  0.7616666666666667
#
# Epoch 00047: val_sparse_categorical_accuracy did not improve from 0.76667
# 28/28 [==============================] - 5s 192ms/step - loss: 0.7237 - sparse_categorical_accuracy: 0.7350 - val_loss: 0.7257 - val_sparse_categorical_accuracy: 0.7617 - lr: 4.6054e-06
#
# Epoch 00048: LearningRateScheduler setting learning rate to 4.605366583984378e-06.
# Epoch 48/50
# 28/28 [==============================] - ETA: 0s - loss: 0.7409 - sparse_categorical_accuracy: 0.7450 - train_f1_score :  0.8135714285714286  - val_f1_score :  0.765
#
# Epoch 00048: val_sparse_categorical_accuracy did not improve from 0.76667
# 28/28 [==============================] - 5s 189ms/step - loss: 0.7409 - sparse_categorical_accuracy: 0.7450 - val_loss: 0.7253 - val_sparse_categorical_accuracy: 0.7650 - lr: 4.6054e-06
#
# Epoch 00049: LearningRateScheduler setting learning rate to 4.605366583984378e-06.
# Epoch 49/50
# 28/28 [==============================] - ETA: 0s - loss: 0.7586 - sparse_categorical_accuracy: 0.7429 - train_f1_score :  0.8128571428571428  - val_f1_score :  0.7666666666666667
#
# Epoch 00049: val_sparse_categorical_accuracy did not improve from 0.76667
# 28/28 [==============================] - 5s 191ms/step - loss: 0.7586 - sparse_categorical_accuracy: 0.7429 - val_loss: 0.7243 - val_sparse_categorical_accuracy: 0.7667 - lr: 4.6054e-06
#
# Epoch 00050: LearningRateScheduler setting learning rate to 2.532951621191408e-06.
# Epoch 50/50
# 28/28 [==============================] - ETA: 0s - loss: 0.7354 - sparse_categorical_accuracy: 0.7421 - train_f1_score :  0.815  - val_f1_score :  0.7616666666666667
#
# Epoch 00050: val_sparse_categorical_accuracy did not improve from 0.76667
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 1.393123386606021e-07.
# 28/28 [==============================] - 5s 190ms/step - loss: 0.7354 - sparse_categorical_accuracy: 0.7421 - val_loss: 0.7242 - val_sparse_categorical_accuracy: 0.7617 - lr: 1.3931e-07

# %%
acc = model_spec_history.history['sparse_categorical_accuracy']
val_acc = model_spec_history.history['val_sparse_categorical_accuracy']

loss = model_spec_history.history['loss']
val_loss = model_spec_history.history['val_loss']

f1 = metrics.history['train_f1_score']
val_f1 = metrics.history['val_f1_score']

epochs_range = range(50)

#plt.figure(figsize=(8, 8))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.show()

plt.plot(epochs_range, f1, label='Training micro F1 score')
plt.plot(epochs_range, val_f1, label='Validation micro F1 score')
plt.legend(loc='lower right')
plt.title('Training and Validation F1 Score')
plt.show()

#plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
model_raw1.save('Model_raw_1_0.1517_final.h5')

# %%
model_raw1 = load_model('/content/Model_raw_1_0.1517_final.h5')

# %%
## as discussed above, please write the LSTM
y_pred = m_spec.predict(X_test_spectrogram)
y_pred = np.argmax(y_pred, axis = 1)

# %%
print('Classification Report')
print(classification_report(y_test.values, y_pred))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.81      0.73      0.77        60
#            1       0.75      0.78      0.76        60
#            2       0.60      0.70      0.65        60
#            3       0.61      0.55      0.58        60
#            4       0.94      0.82      0.87        60
#            5       0.73      0.77      0.75        60
#            6       0.80      0.78      0.79        60
#            7       0.60      0.67      0.63        60
#            8       0.79      0.75      0.77        60
#            9       0.79      0.80      0.79        60
#
#     accuracy                           0.73       600
#    macro avg       0.74      0.73      0.74       600
# weighted avg       0.74      0.73      0.74       600

# %%
ax= plt.subplot()
sns.heatmap(confusion_matrix(y_test.values, y_pred), annot=True, ax = ax, fmt='g', cmap='Greens') #annot=True to annotate cells

ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels') 
ax.set_title('Confusion Matrix')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
m_spec.save('Model_Spect_1_0.805_final.h5')

# %%
m_spec = load_model('/content/Model_Spect_1_0.805_final.h5')
plot_model(m_spec, show_shapes=True, show_layer_names=True)

# %% [markdown]
# ### 3. Data augmentation with raw features
#
# Till now we have done with 2000 samples only. It is very less data. We are giving the process of generating augmented data below.
#
# There are two types of augmentation:
# 1. time stretching - Time stretching either increases or decreases the length of the file. For time stretching we move the file 30% faster or slower
# 2. pitch shifting - pitch shifting moves the frequencies higher or lower. For pitch shifting we shift up or down one half-step.

# %%
## generating augmented data. 
def generate_augmented_data(file_path, label):
    augmented_data = []
    samples = load_wav(file_path,get_duration=False)
    augmented_data.append(samples)
    for time_value in [0.7, 1, 1.3]:
        for pitch_value in [-1, 0, 1]:
            time_stretch_data = librosa.effects.time_stretch(samples, rate=time_value)
            final_data = librosa.effects.pitch_shift(time_stretch_data, sr=sample_rate, n_steps=pitch_value)
            augmented_data.append(final_data)
    return augmented_data, np.full(len(augmented_data), label)

# %%
Y = df_audio['label'].astype("int32")

# %%
temp_path, temp_lab = df_audio.iloc[1].path, Y.iloc[1]
aug_temp1,auj= generate_augmented_data(temp_path, temp_lab)

# %% [markdown]
# ## Follow the steps
#
# 1. Split data 'df_audio' into train and test (80-20 split)
#
# 2. We have 2000 data points(1600 train points, 400 test points)

# %%
X_train, X_test, y_train, y_test=train_test_split(df_audio['path'],df_audio['label'],random_state=45,test_size=0.2,stratify=df_audio['label'])

# %% [markdown]
# 3. Do augmentation only on X_train,pass each point of X_train to generate_augmented_data function.After augmentation we will get 14400 train points. Make sure that you are augmenting the corresponding class labels (y_train) also.
# 4. Preprocess your X_test using load_wav function.
# 5. Convert the augmented_train_data and test_data to numpy arrays.
# 6. Perform padding and masking on augmented_train_data and test_data.
# 7. After padding define the model similar to model 1 and fit the data

# %% [markdown]
# <font color='red'> Note </font> - While fitting your model on the augmented data for model 3 you might face Resource exhaust error. One simple hack to avoid that is save the augmented_train_data,augment_y_train,test_data and y_test to Drive or into your local system. Then restart the runtime so that now you can train your model with full RAM capacity. Upload these files again in the new runtime session perform padding and masking and then fit your model.

# %%
a = Parallel(n_jobs=-1, verbose = 1)(delayed(generate_augmented_data)(i, j) for i, j in zip(df_audio.path,Y.values))
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:   12.4s
# [Parallel(n_jobs=-1)]: Done 196 tasks      | elapsed:   39.3s
# [Parallel(n_jobs=-1)]: Done 446 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 796 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 1246 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done 1796 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=-1)]: Done 2000 out of 2000 | elapsed:  6.0min finished

# %%
a = np.array(a)
New_samples = a[:,0].ravel()
New_labels = a[:,1].astype('int32').ravel()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   """Entry point for launching an IPython kernel.

# %%
len(New_samples), len(New_labels)
# Out:
# (20000, 20000)

# %%
# Shuffling the above dataset, don't change the random state
New_samples, New_labels = shuffle(New_samples, New_labels, random_state=33)

# %%
X_train, X_test, y_train, y_test = train_test_split(New_samples, New_labels, test_size = 0.3, stratify = New_labels, random_state = 45)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((14000,), (6000,), (14000,), (6000,))

# %%
X_train_mask = np.array([np.ones(g.shape[0]) for g in X_train])
X_train_mask.shape
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   """Entry point for launching an IPython kernel.
# (14000,)

# %%
X_test_mask = np.array([np.ones(g.shape[0]) for g in X_test])
X_test_mask.shape
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   """Entry point for launching an IPython kernel.
# (6000,)

# %%
max_length  = 17640
X_train_mask[-50].shape, X_train[-50].shape
# Out:
# ((7770,), (7770,))

# %%
X_train_pad_seq = pad_sequences(X_train, maxlen=max_length, padding='post', dtype = np.float32, truncating='post')
X_train_mask = pad_sequences(X_train_mask, maxlen=max_length, padding='post', dtype = bool, truncating='post')

# %%
X_test_pad_seq = pad_sequences(X_test, maxlen=max_length, padding='post', dtype = np.float32, truncating='post')
X_test_mask = pad_sequences(X_test_mask, maxlen=max_length, padding='post', dtype = bool, truncating='post')

# %%
X_test_mask
# Out:
# array([[ True,  True,  True, ..., False, False, False],
#        [ True,  True,  True, ..., False, False, False],
#        [ True,  True,  True, ..., False, False, False],
#        ...,
#        [ True,  True,  True, ..., False, False, False],
#        [ True,  True,  True, ..., False, False, False],
#        [ True,  True,  True, ..., False, False, False]])

# %%
X_T_pad = tf.expand_dims(X_train_pad_seq, axis = 2)
X_T_pad.shape, X_T_pad[0].shape
# Out:
# (TensorShape([14000, 17640, 1]), TensorShape([17640, 1]))

# %%
X_Te_pad = tf.expand_dims(X_test_pad_seq, axis = 2)
X_Te_pad.shape, X_Te_pad[0].shape
# Out:
# (TensorShape([6000, 17640, 1]), TensorShape([17640, 1]))

# %%
td1 = tf.data.Dataset.from_tensor_slices((X_T_pad, X_train_mask))
td2 = tf.data.Dataset.from_tensor_slices((y_train))
td = tf.data.Dataset.zip((td1, td2))

# %%
BATCH_SIZE = 128
SHUFFLE_BUFFER_SIZE = 100
train_dataset = td.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)

# %%
td1 = tf.data.Dataset.from_tensor_slices((X_Te_pad, X_test_mask))
td2 = tf.data.Dataset.from_tensor_slices((y_test))
td = tf.data.Dataset.zip((td1, td2))

# %%
test_dataset = td.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)

# %%
Train = [X_T_pad, X_train_mask]
Val = [X_Te_pad, X_test_mask]

# %%
Train_data = (Train, y_train)
Val_data = (Val, y_test)

# %%
del a

# %%
#Model:3- Data augmentation with raw features:

tf.keras.backend.clear_session()
class Metrics(tf.keras.callbacks.Callback):
    
    def __init__(self, x = None, y = None):
        self.training_data = x 
        self.validation_data = y
    
    def on_train_begin(self, logs = {}):
        ## on begin of training, we are creating a instance varible called history
        self.history={'train_f1_score': [], 'val_f1_score': []}

        
    def on_epoch_end(self, epoch, logs = {}):
        ## on end of each epoch, we will get logs and update the self.history dict
        train_predict = self.model.predict(self.training_data[0], batch_size = 128)
        train_bin = np.argmax(train_predict, axis = 1)
        train_targ = self.training_data[1]
        _train_f1 = f1_score(train_targ, train_bin, average = 'micro')
        
         
        val_predict = self.model.predict(self.validation_data[0], batch_size = 128)
        val_bin = np.argmax(val_predict, axis = 1)
        val_targ = self.validation_data[1]
        _val_f1 = f1_score(val_targ, val_bin, average = 'micro')
             
        self.history['val_f1_score'].append(_val_f1)
        self.history['train_f1_score'].append(_train_f1)
        
        print(' - train_f1_score : ', _train_f1, ' - val_f1_score : ', _val_f1)
        return

# %%
def changeLearningRate(epoch):
    global initial_learningrate
    epoch = epoch + 1
    if epoch % 5 == 0:
        initial_learningrate *= 0.55
    return initial_learningrate

# %%
import os
save = 'model_aug_raw_save/*.hdf5'
r = glob.glob(save)
for i in r:
    os.remove(i)

# %%
filepath="model_aug_raw_save/model-{epoch:02d}-{val_sparse_categorical_accuracy:.4f}.hdf5"
checkpoint = ModelCheckpoint(filepath=filepath, monitor='val_sparse_categorical_accuracy',  verbose=1, save_best_only=True, mode='max')
reducelr = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.001, patience = 1, verbose = 1, mode = 'min')

lrschedule = LearningRateScheduler(changeLearningRate, verbose=1)
initial_learningrate=0.001

# %%
metrics = Metrics(Train_data, Val_data)
callbacks = [metrics, checkpoint, reducelr, lrschedule]
reg = tf.keras.regularizers.L2(l2=0.01)

# %%
tf.keras.backend.clear_session()
input_layer = Input(shape=(17640,1), name = 'input_layer')
input_mask = Input(shape=(17640,), name = 'mask_layer', dtype=bool)
ls = LSTM(units = 128, name = 'LSTM')(input_layer, mask = input_mask)
ls = BatchNormalization()(ls)
dc1 = Dense(512,activation='relu',kernel_initializer=tf.keras.initializers.he_normal(seed = 30), name = 'FC2')(ls)
dc1 = Dropout(0.35)(dc1)
out = Dense(10,activation='softmax',kernel_initializer=tf.keras.initializers.glorot_normal(seed = 30), name = 'FC3')(dc1)

# %%
model_aug_raw = Model(inputs = [input_layer,input_mask], outputs = out)

# %%
model_aug_raw.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_layer (InputLayer)       [(None, 17640, 1)]   0           []
#
#  mask_layer (InputLayer)        [(None, 17640)]      0           []
#
#  LSTM (LSTM)                    (None, 128)          66560       ['input_layer[0][0]',
#                                                                   'mask_layer[0][0]']
#
#  batch_normalization (BatchNorm  (None, 128)         512         ['LSTM[0][0]']
#  alization)
#
#  FC2 (Dense)                    (None, 512)          66048       ['batch_normalization[0][0]']
#
#  dropout (Dropout)              (None, 512)          0           ['FC2[0][0]']
#
#  FC3 (Dense)                    (None, 10)           5130        ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 138,250
# Trainable params: 137,994
# Non-trainable params: 256
# __________________________________________________________________________________________________

# %%
model_aug_raw.compile(optimizer=tf.keras.optimizers.RMSprop(0.001),loss='sparse_categorical_crossentropy',metrics=['sparse_categorical_accuracy'])

# %%
train_steps = X_train.shape[0]//100
valid_steps = X_test.shape[0]//100
train_steps
# Out:
# 140

# %%
#tf.keras.backend.clear_session()
model_spec_history = m_spec.fit(X_train_spectrogram, y_train.values, batch_size =50, validation_data = (X_test_spectrogram, y_test.values), epochs=50, verbose=1, callbacks=callbacks)

#model_history = model_aug_raw.fit(train_dataset, validation_data = test_dataset, epochs = 5, verbose = 1, callbacks = callbacks)
# Out:
# Epoch 00001: LearningRateScheduler setting learning rate to 0.001.
# Epoch 1/50
# 28/28 [==============================] - ETA: 0s - loss: 2.7174 - sparse_categorical_accuracy: 0.2114 - train_f1_score :  0.13214285714285715  - val_f1_score :  0.13
#
# Epoch 00001: val_sparse_categorical_accuracy improved from -inf to 0.13000, saving model to model_spec_save/model-01-0.1300.hdf5
# 28/28 [==============================] - 8s 225ms/step - loss: 2.7174 - sparse_categorical_accuracy: 0.2114 - val_loss: 2.7606 - val_sparse_categorical_accuracy: 0.1300 - lr: 0.0010
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.001.
# Epoch 2/50
# 28/28 [==============================] - ETA: 0s - loss: 2.0904 - sparse_categorical_accuracy: 0.3350 - train_f1_score :  0.12642857142857142  - val_f1_score :  0.12833333333333333
#
# Epoch 00002: val_sparse_categorical_accuracy did not improve from 0.13000
#
# Epoch 00002: ReduceLROnPlateau reducing learning rate to 5.500000261235982e-05.
# 28/28 [==============================] - 5s 188ms/step - loss: 2.0904 - sparse_categorical_accuracy: 0.3350 - val_loss: 3.2726 - val_sparse_categorical_accuracy: 0.1283 - lr: 5.5000e-05
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.001.
# Epoch 3/50
# 28/28 [==============================] - ETA: 0s - loss: 1.7642 - sparse_categorical_accuracy: 0.4336 - train_f1_score :  0.2292857142857143  - val_f1_score :  0.21499999999999997
#
# Epoch 00003: val_sparse_categorical_accuracy improved from 0.13000 to 0.21500, saving model to model_spec_save/model-03-0.2150.hdf5
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 5.500000261235982e-05.
# 28/28 [==============================] - 5s 188ms/step - loss: 1.7642 - sparse_categorical_accuracy: 0.4336 - val_loss: 3.1199 - val_sparse_categorical_accuracy: 0.2150 - lr: 5.5000e-05
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.001.
# Epoch 4/50
# 28/28 [==============================] - ETA: 0s - loss: 1.5385 - sparse_categorical_accuracy: 0.4657 - train_f1_score :  0.13214285714285715  - val_f1_score :  0.12333333333333335
#
# Epoch 00004: val_sparse_categorical_accuracy did not improve from 0.21500
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 5.500000261235982e-05.
# 28/28 [==============================] - 5s 182ms/step - loss: 1.5385 - sparse_categorical_accuracy: 0.4657 - val_loss: 3.3822 - val_sparse_categorical_accuracy: 0.1233 - lr: 5.5000e-05
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.00055.
# Epoch 5/50
# 28/28 [==============================] - ETA: 0s - loss: 1.5168 - sparse_categorical_accuracy: 0.4707 - train_f1_score :  0.1442857142857143  - val_f1_score :  0.14333333333333334
#
# Epoch 00005: val_sparse_categorical_accuracy did not improve from 0.21500
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 3.0249999836087226e-05.
# 28/28 [==============================] - 5s 188ms/step - loss: 1.5168 - sparse_categorical_accuracy: 0.4707 - val_loss: 2.9602 - val_sparse_categorical_accuracy: 0.1433 - lr: 3.0250e-05
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.00055.
# Epoch 6/50
# 28/28 [==============================] - ETA: 0s - loss: 1.3212 - sparse_categorical_accuracy: 0.5443 - train_f1_score :  0.1707142857142857  - val_f1_score :  0.16833333333333333
#
# Epoch 00006: val_sparse_categorical_accuracy did not improve from 0.21500
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 3.0249999836087226e-05.
# 28/28 [==============================] - 5s 190ms/step - loss: 1.3212 - sparse_categorical_accuracy: 0.5443 - val_loss: 2.9514 - val_sparse_categorical_accuracy: 0.1683 - lr: 3.0250e-05
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.00055.
# Epoch 7/50
# 28/28 [==============================] - ETA: 0s - loss: 1.2809 - sparse_categorical_accuracy: 0.5457 - train_f1_score :  0.20928571428571427  - val_f1_score :  0.20333333333333334
#
# Epoch 00007: val_sparse_categorical_accuracy did not improve from 0.21500
# 28/28 [==============================] - 5s 194ms/step - loss: 1.2809 - sparse_categorical_accuracy: 0.5457 - val_loss: 2.4114 - val_sparse_categorical_accuracy: 0.2033 - lr: 5.5000e-04
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.00055.
# Epoch 8/50
# 28/28 [==============================] - ETA: 0s - loss: 1.2160 - sparse_categorical_accuracy: 0.5686 - train_f1_score :  0.23642857142857143  - val_f1_score :  0.225
#
# Epoch 00008: val_sparse_categorical_accuracy improved from 0.21500 to 0.22500, saving model to model_spec_save/model-08-0.2250.hdf5
# 28/28 [==============================] - 5s 187ms/step - loss: 1.2160 - sparse_categorical_accuracy: 0.5686 - val_loss: 2.2804 - val_sparse_categorical_accuracy: 0.2250 - lr: 5.5000e-04
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.00055.
# Epoch 9/50
# 28/28 [==============================] - ETA: 0s - loss: 1.2074 - sparse_categorical_accuracy: 0.5579 - train_f1_score :  0.26571428571428574  - val_f1_score :  0.255
#
# Epoch 00009: val_sparse_categorical_accuracy improved from 0.22500 to 0.25500, saving model to model_spec_save/model-09-0.2550.hdf5
# 28/28 [==============================] - 5s 188ms/step - loss: 1.2074 - sparse_categorical_accuracy: 0.5579 - val_loss: 2.1611 - val_sparse_categorical_accuracy: 0.2550 - lr: 5.5000e-04
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.00030250000000000003.
# Epoch 10/50
# 28/28 [==============================] - ETA: 0s - loss: 1.1878 - sparse_categorical_accuracy: 0.5800 - train_f1_score :  0.2807142857142857  - val_f1_score :  0.29
#
# Epoch 00010: val_sparse_categorical_accuracy improved from 0.25500 to 0.29000, saving model to model_spec_save/model-10-0.2900.hdf5
# 28/28 [==============================] - 5s 191ms/step - loss: 1.1878 - sparse_categorical_accuracy: 0.5800 - val_loss: 2.1056 - val_sparse_categorical_accuracy: 0.2900 - lr: 3.0250e-04
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.00030250000000000003.
# Epoch 11/50
# 28/28 [==============================] - ETA: 0s - loss: 1.1154 - sparse_categorical_accuracy: 0.5950 - train_f1_score :  0.3271428571428571  - val_f1_score :  0.33666666666666667
#
# Epoch 00011: val_sparse_categorical_accuracy improved from 0.29000 to 0.33667, saving model to model_spec_save/model-11-0.3367.hdf5
# 28/28 [==============================] - 5s 189ms/step - loss: 1.1154 - sparse_categorical_accuracy: 0.5950 - val_loss: 1.8718 - val_sparse_categorical_accuracy: 0.3367 - lr: 3.0250e-04
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.00030250000000000003.
# Epoch 12/50
# 28/28 [==============================] - ETA: 0s - loss: 1.0935 - sparse_categorical_accuracy: 0.6079 - train_f1_score :  0.43642857142857144  - val_f1_score :  0.41833333333333333
#
# Epoch 00012: val_sparse_categorical_accuracy improved from 0.33667 to 0.41833, saving model to model_spec_save/model-12-0.4183.hdf5
# 28/28 [==============================] - 5s 186ms/step - loss: 1.0935 - sparse_categorical_accuracy: 0.6079 - val_loss: 1.6357 - val_sparse_categorical_accuracy: 0.4183 - lr: 3.0250e-04
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.00030250000000000003.
# Epoch 13/50
# 28/28 [==============================] - ETA: 0s - loss: 1.0074 - sparse_categorical_accuracy: 0.6571 - train_f1_score :  0.5314285714285715  - val_f1_score :  0.5
#
# Epoch 00013: val_sparse_categorical_accuracy improved from 0.41833 to 0.50000, saving model to model_spec_save/model-13-0.5000.hdf5
# 28/28 [==============================] - 5s 194ms/step - loss: 1.0074 - sparse_categorical_accuracy: 0.6571 - val_loss: 1.4631 - val_sparse_categorical_accuracy: 0.5000 - lr: 3.0250e-04
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.00030250000000000003.
# Epoch 14/50
# 28/28 [==============================] - ETA: 0s - loss: 1.0041 - sparse_categorical_accuracy: 0.6300 - train_f1_score :  0.6271428571428571  - val_f1_score :  0.5916666666666667
#
# Epoch 00014: val_sparse_categorical_accuracy improved from 0.50000 to 0.59167, saving model to model_spec_save/model-14-0.5917.hdf5
# 28/28 [==============================] - 5s 187ms/step - loss: 1.0041 - sparse_categorical_accuracy: 0.6300 - val_loss: 1.2437 - val_sparse_categorical_accuracy: 0.5917 - lr: 3.0250e-04
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.00016637500000000002.
# Epoch 15/50
# 28/28 [==============================] - ETA: 0s - loss: 0.9859 - sparse_categorical_accuracy: 0.6586 - train_f1_score :  0.6157142857142858  - val_f1_score :  0.5983333333333334
#
# Epoch 00015: val_sparse_categorical_accuracy improved from 0.59167 to 0.59833, saving model to model_spec_save/model-15-0.5983.hdf5
# 28/28 [==============================] - 5s 189ms/step - loss: 0.9859 - sparse_categorical_accuracy: 0.6586 - val_loss: 1.2326 - val_sparse_categorical_accuracy: 0.5983 - lr: 1.6638e-04
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.00016637500000000002.
# Epoch 16/50
# 28/28 [==============================] - ETA: 0s - loss: 1.0069 - sparse_categorical_accuracy: 0.6521 - train_f1_score :  0.7100000000000001  - val_f1_score :  0.6633333333333333
#
# Epoch 00016: val_sparse_categorical_accuracy improved from 0.59833 to 0.66333, saving model to model_spec_save/model-16-0.6633.hdf5
# 28/28 [==============================] - 5s 187ms/step - loss: 1.0069 - sparse_categorical_accuracy: 0.6521 - val_loss: 1.0781 - val_sparse_categorical_accuracy: 0.6633 - lr: 1.6638e-04
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.00016637500000000002.
# Epoch 17/50
# 28/28 [==============================] - ETA: 0s - loss: 0.9239 - sparse_categorical_accuracy: 0.6750 - train_f1_score :  0.6871428571428572  - val_f1_score :  0.6333333333333333
#
# Epoch 00017: val_sparse_categorical_accuracy did not improve from 0.66333
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 9.150625046459027e-06.
# 28/28 [==============================] - 5s 186ms/step - loss: 0.9239 - sparse_categorical_accuracy: 0.6750 - val_loss: 1.1208 - val_sparse_categorical_accuracy: 0.6333 - lr: 9.1506e-06
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.00016637500000000002.
# Epoch 18/50
# 28/28 [==============================] - ETA: 0s - loss: 0.9329 - sparse_categorical_accuracy: 0.6686 - train_f1_score :  0.7107142857142857  - val_f1_score :  0.645
#
# Epoch 00018: val_sparse_categorical_accuracy did not improve from 0.66333
# 28/28 [==============================] - 5s 187ms/step - loss: 0.9329 - sparse_categorical_accuracy: 0.6686 - val_loss: 1.0476 - val_sparse_categorical_accuracy: 0.6450 - lr: 1.6638e-04
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.00016637500000000002.
# Epoch 19/50
# 28/28 [==============================] - ETA: 0s - loss: 0.9277 - sparse_categorical_accuracy: 0.6814 - train_f1_score :  0.7278571428571429  - val_f1_score :  0.6633333333333333
#
# Epoch 00019: val_sparse_categorical_accuracy did not improve from 0.66333
# 28/28 [==============================] - 5s 186ms/step - loss: 0.9277 - sparse_categorical_accuracy: 0.6814 - val_loss: 1.0139 - val_sparse_categorical_accuracy: 0.6633 - lr: 1.6638e-04
#
# Epoch 00020: LearningRateScheduler setting learning rate to 9.150625000000002e-05.
# Epoch 20/50
# 28/28 [==============================] - ETA: 0s - loss: 0.9012 - sparse_categorical_accuracy: 0.6829 - train_f1_score :  0.7492857142857143  - val_f1_score :  0.655
#
# Epoch 00020: val_sparse_categorical_accuracy did not improve from 0.66333
# 28/28 [==============================] - 5s 186ms/step - loss: 0.9012 - sparse_categorical_accuracy: 0.6829 - val_loss: 0.9921 - val_sparse_categorical_accuracy: 0.6550 - lr: 9.1506e-05
#
# Epoch 00021: LearningRateScheduler setting learning rate to 9.150625000000002e-05.
# Epoch 21/50
# 28/28 [==============================] - ETA: 0s - loss: 0.8910 - sparse_categorical_accuracy: 0.6814 - train_f1_score :  0.7571428571428571  - val_f1_score :  0.69
#
# Epoch 00021: val_sparse_categorical_accuracy improved from 0.66333 to 0.69000, saving model to model_spec_save/model-21-0.6900.hdf5
# 28/28 [==============================] - 5s 190ms/step - loss: 0.8910 - sparse_categorical_accuracy: 0.6814 - val_loss: 0.9540 - val_sparse_categorical_accuracy: 0.6900 - lr: 9.1506e-05
#
# Epoch 00022: LearningRateScheduler setting learning rate to 9.150625000000002e-05.
# Epoch 22/50
# 28/28 [==============================] - ETA: 0s - loss: 0.8934 - sparse_categorical_accuracy: 0.6864 - train_f1_score :  0.7592857142857142  - val_f1_score :  0.685
#
# Epoch 00022: val_sparse_categorical_accuracy did not improve from 0.69000
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 5.032843655499164e-06.
# 28/28 [==============================] - 5s 190ms/step - loss: 0.8934 - sparse_categorical_accuracy: 0.6864 - val_loss: 0.9660 - val_sparse_categorical_accuracy: 0.6850 - lr: 5.0328e-06
#
# Epoch 00023: LearningRateScheduler setting learning rate to 9.150625000000002e-05.
# Epoch 23/50
# 28/28 [==============================] - ETA: 0s - loss: 0.8873 - sparse_categorical_accuracy: 0.6900 - train_f1_score :  0.7485714285714286  - val_f1_score :  0.6916666666666667
#
# Epoch 00023: val_sparse_categorical_accuracy improved from 0.69000 to 0.69167, saving model to model_spec_save/model-23-0.6917.hdf5
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 5.032843655499164e-06.
# 28/28 [==============================] - 5s 190ms/step - loss: 0.8873 - sparse_categorical_accuracy: 0.6900 - val_loss: 0.9600 - val_sparse_categorical_accuracy: 0.6917 - lr: 5.0328e-06
#
# Epoch 00024: LearningRateScheduler setting learning rate to 9.150625000000002e-05.
# Epoch 24/50
# 28/28 [==============================] - ETA: 0s - loss: 0.8583 - sparse_categorical_accuracy: 0.7000 - train_f1_score :  0.7485714285714286  - val_f1_score :  0.6683333333333333
#
# Epoch 00024: val_sparse_categorical_accuracy did not improve from 0.69167
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 5.032843655499164e-06.
# 28/28 [==============================] - 5s 189ms/step - loss: 0.8583 - sparse_categorical_accuracy: 0.7000 - val_loss: 0.9796 - val_sparse_categorical_accuracy: 0.6683 - lr: 5.0328e-06
#
# Epoch 00025: LearningRateScheduler setting learning rate to 5.032843750000002e-05.
# Epoch 25/50
# 28/28 [==============================] - ETA: 0s - loss: 0.8664 - sparse_categorical_accuracy: 0.6914 - train_f1_score :  0.7664285714285715  - val_f1_score :  0.695
#
# Epoch 00025: val_sparse_categorical_accuracy improved from 0.69167 to 0.69500, saving model to model_spec_save/model-25-0.6950.hdf5
# 28/28 [==============================] - 5s 190ms/step - loss: 0.8664 - sparse_categorical_accuracy: 0.6914 - val_loss: 0.9389 - val_sparse_categorical_accuracy: 0.6950 - lr: 5.0328e-05
#
# Epoch 00026: LearningRateScheduler setting learning rate to 5.032843750000002e-05.
# Epoch 26/50
# 28/28 [==============================] - ETA: 0s - loss: 0.8744 - sparse_categorical_accuracy: 0.7129 - train_f1_score :  0.7735714285714286  - val_f1_score :  0.6883333333333334
#
# Epoch 00026: val_sparse_categorical_accuracy did not improve from 0.69500
# 28/28 [==============================] - 5s 187ms/step - loss: 0.8744 - sparse_categorical_accuracy: 0.7129 - val_loss: 0.9193 - val_sparse_categorical_accuracy: 0.6883 - lr: 5.0328e-05
#
# Epoch 00027: LearningRateScheduler setting learning rate to 5.032843750000002e-05.
# Epoch 27/50
# 28/28 [==============================] - ETA: 0s - loss: 0.8584 - sparse_categorical_accuracy: 0.7014 - train_f1_score :  0.7699999999999999  - val_f1_score :  0.7
#
# Epoch 00027: val_sparse_categorical_accuracy improved from 0.69500 to 0.70000, saving model to model_spec_save/model-27-0.7000.hdf5
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 2.7680641505867245e-06.
# 28/28 [==============================] - 5s 191ms/step - loss: 0.8584 - sparse_categorical_accuracy: 0.7014 - val_loss: 0.9228 - val_sparse_categorical_accuracy: 0.7000 - lr: 2.7681e-06
#
# Epoch 00028: LearningRateScheduler setting learning rate to 5.032843750000002e-05.
# Epoch 28/50
# 28/28 [==============================] - ETA: 0s - loss: 0.8433 - sparse_categorical_accuracy: 0.7207 - train_f1_score :  0.7607142857142857  - val_f1_score :  0.6816666666666666
#
# Epoch 00028: val_sparse_categorical_accuracy did not improve from 0.70000
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 2.7680641505867245e-06.
# 28/28 [==============================] - 5s 186ms/step - loss: 0.8433 - sparse_categorical_accuracy: 0.7207 - val_loss: 0.9315 - val_sparse_categorical_accuracy: 0.6817 - lr: 2.7681e-06
#
# Epoch 00029: LearningRateScheduler setting learning rate to 5.032843750000002e-05.
# Epoch 29/50
# 28/28 [==============================] - ETA: 0s - loss: 0.8263 - sparse_categorical_accuracy: 0.7207 - train_f1_score :  0.7835714285714286  - val_f1_score :  0.72
#
# Epoch 00029: val_sparse_categorical_accuracy improved from 0.70000 to 0.72000, saving model to model_spec_save/model-29-0.7200.hdf5
# 28/28 [==============================] - 5s 191ms/step - loss: 0.8263 - sparse_categorical_accuracy: 0.7207 - val_loss: 0.8937 - val_sparse_categorical_accuracy: 0.7200 - lr: 5.0328e-05
#
# Epoch 00030: LearningRateScheduler setting learning rate to 2.768064062500001e-05.
# Epoch 30/50
# 28/28 [==============================] - ETA: 0s - loss: 0.7864 - sparse_categorical_accuracy: 0.7250 - train_f1_score :  0.7942857142857144  - val_f1_score :  0.7316666666666667
#
# Epoch 00030: val_sparse_categorical_accuracy improved from 0.72000 to 0.73167, saving model to model_spec_save/model-30-0.7317.hdf5
# 28/28 [==============================] - 5s 190ms/step - loss: 0.7864 - sparse_categorical_accuracy: 0.7250 - val_loss: 0.8741 - val_sparse_categorical_accuracy: 0.7317 - lr: 2.7681e-05
#
# Epoch 00031: LearningRateScheduler setting learning rate to 2.768064062500001e-05.
# Epoch 31/50
# 28/28 [==============================] - ETA: 0s - loss: 0.8109 - sparse_categorical_accuracy: 0.7343 - train_f1_score :  0.7892857142857143  - val_f1_score :  0.7233333333333334
#
# Epoch 00031: val_sparse_categorical_accuracy did not improve from 0.73167
# 28/28 [==============================] - 5s 187ms/step - loss: 0.8109 - sparse_categorical_accuracy: 0.7343 - val_loss: 0.8731 - val_sparse_categorical_accuracy: 0.7233 - lr: 2.7681e-05
#
# Epoch 00032: LearningRateScheduler setting learning rate to 2.768064062500001e-05.
# Epoch 32/50
# 28/28 [==============================] - ETA: 0s - loss: 0.8100 - sparse_categorical_accuracy: 0.7207 - train_f1_score :  0.7942857142857144  - val_f1_score :  0.7250000000000001
#
# Epoch 00032: val_sparse_categorical_accuracy did not improve from 0.73167
# 28/28 [==============================] - 5s 191ms/step - loss: 0.8100 - sparse_categorical_accuracy: 0.7207 - val_loss: 0.8690 - val_sparse_categorical_accuracy: 0.7250 - lr: 2.7681e-05
#
# Epoch 00033: LearningRateScheduler setting learning rate to 2.768064062500001e-05.
# Epoch 33/50
# 28/28 [==============================] - ETA: 0s - loss: 0.8372 - sparse_categorical_accuracy: 0.7150 - train_f1_score :  0.7985714285714286  - val_f1_score :  0.7216666666666668
#
# Epoch 00033: val_sparse_categorical_accuracy did not improve from 0.73167
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 1.522435222796048e-06.
# 28/28 [==============================] - 5s 188ms/step - loss: 0.8372 - sparse_categorical_accuracy: 0.7150 - val_loss: 0.8699 - val_sparse_categorical_accuracy: 0.7217 - lr: 1.5224e-06
#
# Epoch 00034: LearningRateScheduler setting learning rate to 2.768064062500001e-05.
# Epoch 34/50
# 28/28 [==============================] - ETA: 0s - loss: 0.8036 - sparse_categorical_accuracy: 0.7279 - train_f1_score :  0.7964285714285714  - val_f1_score :  0.7299999999999999
#
# Epoch 00034: val_sparse_categorical_accuracy did not improve from 0.73167
# 28/28 [==============================] - 5s 188ms/step - loss: 0.8036 - sparse_categorical_accuracy: 0.7279 - val_loss: 0.8625 - val_sparse_categorical_accuracy: 0.7300 - lr: 2.7681e-05
#
# Epoch 00035: LearningRateScheduler setting learning rate to 1.5224352343750007e-05.
# Epoch 35/50
# 28/28 [==============================] - ETA: 0s - loss: 0.8139 - sparse_categorical_accuracy: 0.7307 - train_f1_score :  0.7957142857142857  - val_f1_score :  0.7216666666666668
#
# Epoch 00035: val_sparse_categorical_accuracy did not improve from 0.73167
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 8.373393575311638e-07.
# 28/28 [==============================] - 5s 188ms/step - loss: 0.8139 - sparse_categorical_accuracy: 0.7307 - val_loss: 0.8680 - val_sparse_categorical_accuracy: 0.7217 - lr: 8.3734e-07
#
# Epoch 00036: LearningRateScheduler setting learning rate to 1.5224352343750007e-05.
# Epoch 36/50
# 28/28 [==============================] - ETA: 0s - loss: 0.8137 - sparse_categorical_accuracy: 0.7257 - train_f1_score :  0.7957142857142857  - val_f1_score :  0.72
#
# Epoch 00036: val_sparse_categorical_accuracy did not improve from 0.73167
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 8.373393575311638e-07.
# 28/28 [==============================] - 5s 188ms/step - loss: 0.8137 - sparse_categorical_accuracy: 0.7257 - val_loss: 0.8652 - val_sparse_categorical_accuracy: 0.7200 - lr: 8.3734e-07
#
# Epoch 00037: LearningRateScheduler setting learning rate to 1.5224352343750007e-05.
# Epoch 37/50
# 28/28 [==============================] - ETA: 0s - loss: 0.8571 - sparse_categorical_accuracy: 0.7057 - train_f1_score :  0.8007142857142857  - val_f1_score :  0.7333333333333333
#
# Epoch 00037: val_sparse_categorical_accuracy improved from 0.73167 to 0.73333, saving model to model_spec_save/model-37-0.7333.hdf5
# 28/28 [==============================] - 5s 192ms/step - loss: 0.8571 - sparse_categorical_accuracy: 0.7057 - val_loss: 0.8587 - val_sparse_categorical_accuracy: 0.7333 - lr: 1.5224e-05
#
# Epoch 00038: LearningRateScheduler setting learning rate to 1.5224352343750007e-05.
# Epoch 38/50
# 28/28 [==============================] - ETA: 0s - loss: 0.8135 - sparse_categorical_accuracy: 0.7129 - train_f1_score :  0.7985714285714286  - val_f1_score :  0.7283333333333334
#
# Epoch 00038: val_sparse_categorical_accuracy did not improve from 0.73333
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 8.373393575311638e-07.
# 28/28 [==============================] - 5s 189ms/step - loss: 0.8135 - sparse_categorical_accuracy: 0.7129 - val_loss: 0.8614 - val_sparse_categorical_accuracy: 0.7283 - lr: 8.3734e-07
#
# Epoch 00039: LearningRateScheduler setting learning rate to 1.5224352343750007e-05.
# Epoch 39/50
# 28/28 [==============================] - ETA: 0s - loss: 0.7964 - sparse_categorical_accuracy: 0.7364 - train_f1_score :  0.7985714285714286  - val_f1_score :  0.7233333333333334
#
# Epoch 00039: val_sparse_categorical_accuracy did not improve from 0.73333
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 8.373393575311638e-07.
# 28/28 [==============================] - 5s 191ms/step - loss: 0.7964 - sparse_categorical_accuracy: 0.7364 - val_loss: 0.8589 - val_sparse_categorical_accuracy: 0.7233 - lr: 8.3734e-07
#
# Epoch 00040: LearningRateScheduler setting learning rate to 8.373393789062505e-06.
# Epoch 40/50
# 28/28 [==============================] - ETA: 0s - loss: 0.8252 - sparse_categorical_accuracy: 0.7021 - train_f1_score :  0.7992857142857143  - val_f1_score :  0.7283333333333334
#
# Epoch 00040: val_sparse_categorical_accuracy did not improve from 0.73333
# 28/28 [==============================] - 5s 191ms/step - loss: 0.8252 - sparse_categorical_accuracy: 0.7021 - val_loss: 0.8540 - val_sparse_categorical_accuracy: 0.7283 - lr: 8.3734e-06
#
# Epoch 00041: LearningRateScheduler setting learning rate to 8.373393789062505e-06.
# Epoch 41/50
# 28/28 [==============================] - ETA: 0s - loss: 0.7887 - sparse_categorical_accuracy: 0.7293 - train_f1_score :  0.795  - val_f1_score :  0.7299999999999999
#
# Epoch 00041: val_sparse_categorical_accuracy did not improve from 0.73333
# 28/28 [==============================] - 5s 188ms/step - loss: 0.7887 - sparse_categorical_accuracy: 0.7293 - val_loss: 0.8518 - val_sparse_categorical_accuracy: 0.7300 - lr: 8.3734e-06
#
# Epoch 00042: LearningRateScheduler setting learning rate to 8.373393789062505e-06.
# Epoch 42/50
# 28/28 [==============================] - ETA: 0s - loss: 0.8153 - sparse_categorical_accuracy: 0.7093 - train_f1_score :  0.797142857142857  - val_f1_score :  0.7316666666666667
#
# Epoch 00042: val_sparse_categorical_accuracy did not improve from 0.73333
# 28/28 [==============================] - 5s 189ms/step - loss: 0.8153 - sparse_categorical_accuracy: 0.7093 - val_loss: 0.8480 - val_sparse_categorical_accuracy: 0.7317 - lr: 8.3734e-06
#
# Epoch 00043: LearningRateScheduler setting learning rate to 8.373393789062505e-06.
# Epoch 43/50
# 28/28 [==============================] - ETA: 0s - loss: 0.7576 - sparse_categorical_accuracy: 0.7529 - train_f1_score :  0.8021428571428573  - val_f1_score :  0.735
#
# Epoch 00043: val_sparse_categorical_accuracy improved from 0.73333 to 0.73500, saving model to model_spec_save/model-43-0.7350.hdf5
# 28/28 [==============================] - 5s 189ms/step - loss: 0.7576 - sparse_categorical_accuracy: 0.7529 - val_loss: 0.8452 - val_sparse_categorical_accuracy: 0.7350 - lr: 8.3734e-06
#
# Epoch 00044: LearningRateScheduler setting learning rate to 8.373393789062505e-06.
# Epoch 44/50
# 28/28 [==============================] - ETA: 0s - loss: 0.7959 - sparse_categorical_accuracy: 0.7171 - train_f1_score :  0.8007142857142857  - val_f1_score :  0.7383333333333333
#
# Epoch 00044: val_sparse_categorical_accuracy improved from 0.73500 to 0.73833, saving model to model_spec_save/model-44-0.7383.hdf5
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 4.6053666665102354e-07.
# 28/28 [==============================] - 5s 189ms/step - loss: 0.7959 - sparse_categorical_accuracy: 0.7171 - val_loss: 0.8457 - val_sparse_categorical_accuracy: 0.7383 - lr: 4.6054e-07
#
# Epoch 00045: LearningRateScheduler setting learning rate to 4.605366583984378e-06.
# Epoch 45/50
# 28/28 [==============================] - ETA: 0s - loss: 0.7850 - sparse_categorical_accuracy: 0.7336 - train_f1_score :  0.8000000000000002  - val_f1_score :  0.735
#
# Epoch 00045: val_sparse_categorical_accuracy did not improve from 0.73833
# 28/28 [==============================] - 5s 190ms/step - loss: 0.7850 - sparse_categorical_accuracy: 0.7336 - val_loss: 0.8450 - val_sparse_categorical_accuracy: 0.7350 - lr: 4.6054e-06
#
# Epoch 00046: LearningRateScheduler setting learning rate to 4.605366583984378e-06.
# Epoch 46/50
# 28/28 [==============================] - ETA: 0s - loss: 0.8069 - sparse_categorical_accuracy: 0.7179 - train_f1_score :  0.8014285714285714  - val_f1_score :  0.7316666666666667
#
# Epoch 00046: val_sparse_categorical_accuracy did not improve from 0.73833
# 28/28 [==============================] - 5s 188ms/step - loss: 0.8069 - sparse_categorical_accuracy: 0.7179 - val_loss: 0.8445 - val_sparse_categorical_accuracy: 0.7317 - lr: 4.6054e-06
#
# Epoch 00047: LearningRateScheduler setting learning rate to 4.605366583984378e-06.
# Epoch 47/50
# 28/28 [==============================] - ETA: 0s - loss: 0.7883 - sparse_categorical_accuracy: 0.7286 - train_f1_score :  0.8028571428571428  - val_f1_score :  0.7299999999999999
#
# Epoch 00047: val_sparse_categorical_accuracy did not improve from 0.73833
# 28/28 [==============================] - 5s 188ms/step - loss: 0.7883 - sparse_categorical_accuracy: 0.7286 - val_loss: 0.8428 - val_sparse_categorical_accuracy: 0.7300 - lr: 4.6054e-06
#
# Epoch 00048: LearningRateScheduler setting learning rate to 4.605366583984378e-06.
# Epoch 48/50
# 28/28 [==============================] - ETA: 0s - loss: 0.7980 - sparse_categorical_accuracy: 0.7157 - train_f1_score :  0.8021428571428573  - val_f1_score :  0.7333333333333333
#
# Epoch 00048: val_sparse_categorical_accuracy did not improve from 0.73833
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 2.5329515665362126e-07.
# 28/28 [==============================] - 5s 188ms/step - loss: 0.7980 - sparse_categorical_accuracy: 0.7157 - val_loss: 0.8444 - val_sparse_categorical_accuracy: 0.7333 - lr: 2.5330e-07
#
# Epoch 00049: LearningRateScheduler setting learning rate to 4.605366583984378e-06.
# Epoch 49/50
# 28/28 [==============================] - ETA: 0s - loss: 0.7929 - sparse_categorical_accuracy: 0.7314 - train_f1_score :  0.8000000000000002  - val_f1_score :  0.7333333333333333
#
# Epoch 00049: val_sparse_categorical_accuracy did not improve from 0.73833
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 2.5329515665362126e-07.
# 28/28 [==============================] - 5s 188ms/step - loss: 0.7929 - sparse_categorical_accuracy: 0.7314 - val_loss: 0.8438 - val_sparse_categorical_accuracy: 0.7333 - lr: 2.5330e-07
#
# Epoch 00050: LearningRateScheduler setting learning rate to 2.532951621191408e-06.
# Epoch 50/50
# 28/28 [==============================] - ETA: 0s - loss: 0.7924 - sparse_categorical_accuracy: 0.7314 - train_f1_score :  0.8057142857142857  - val_f1_score :  0.735
#
# Epoch 00050: val_sparse_categorical_accuracy did not improve from 0.73833
# 28/28 [==============================] - 5s 186ms/step - loss: 0.7924 - sparse_categorical_accuracy: 0.7314 - val_loss: 0.8425 - val_sparse_categorical_accuracy: 0.7350 - lr: 2.5330e-06

# %%
acc = model_spec_history.history['sparse_categorical_accuracy']
val_acc = model_spec_history.history['val_sparse_categorical_accuracy']

loss = model_spec_history.history['loss']
val_loss = model_spec_history.history['val_loss']

f1 = metrics.history['train_f1_score']
val_f1 = metrics.history['val_f1_score']

epochs_range = range(50)

#plt.figure(figsize=(8, 8))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.show()

plt.plot(epochs_range, f1, label='Training micro F1 score')
plt.plot(epochs_range, val_f1, label='Validation micro F1 score')
plt.legend(loc='lower right')
plt.title('Training and Validation F1 Score')
plt.show()

#plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
model_aug_raw.save('Model_Aug_raw_2_0.1795_final.h5')

# %%
model_raw1 = load_model('/content/Model_Aug_raw_2_0.1795_final.h5')

# %%
y_pred = model_aug_raw.predict(Val)
y_pred = np.argmax(y_pred, axis = 1)

# %%
print('Classification Report')
print(classification_report(y_test, y_pred))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        60
#            1       0.00      0.00      0.00        60
#            2       0.00      0.00      0.00        60
#            3       0.00      0.00      0.00        60
#            4       0.00      0.00      0.00        60
#            5       0.07      0.33      0.12        60
#            6       0.19      0.08      0.12        60
#            7       0.00      0.00      0.00        60
#            8       0.03      0.02      0.02        60
#            9       0.09      0.38      0.15        60
#
#     accuracy                           0.08       600
#    macro avg       0.04      0.08      0.04       600
# weighted avg       0.04      0.08      0.04       600
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
ax= plt.subplot()
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, ax = ax, fmt='g', cmap='Greens')

ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels') 
ax.set_title('Confusion Matrix')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
from tensorflow.keras.utils import plot_model
plot_model(model_aug_raw, show_shapes=True, show_layer_names=True)

# %% [markdown]
# ### 4. Data augmentation with spectogram data
#
# ---

# %% [markdown]
# 1. use convert_to_spectrogram and convert the padded data from train and test data to spectogram data.
# 2. The shape of train data will be 14400 x 64 x 35 and shape of test_data will be 400 x 64 x35
# 3. Define the model similar to model 2 and fit the data

# %%
def convert_to_spectrogram(raw_data):
    '''converting to spectrogram'''
    spectrum = librosa.feature.melspectrogram(y=raw_data, sr=sample_rate, n_mels=64)
    logmel_spectrum = librosa.power_to_db(S=spectrum, ref=np.max)
    return logmel_spectrum

# %%
X_train_spectrogram = []
for j in X_train_pad_seq:
    l = convert_to_spectrogram(j)
    X_train_spectrogram.append(l)
X_train_spectrogram = np.array(X_train_spectrogram)

# %%
X_test_spectrogram = []
for j in X_test_pad_seq:
    l = convert_to_spectrogram(j)
    X_test_spectrogram.append(l)
X_test_spectrogram = np.array(X_test_spectrogram)

# %%
def grader_spectrogram():
    flag_shape = (X_train_spectrogram.shape==(14000,64, 35)) and (X_test_spectrogram.shape == (6000, 64, 35))
    return flag_shape
grader_spectrogram()
# Out:
# False

# %%
td1 = tf.data.Dataset.from_tensor_slices((X_train_spectrogram, y_train))

# %%
BATCH_SIZE = 128
SHUFFLE_BUFFER_SIZE = 100
train_spec_dataset = td1.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)

# %%
td1 = tf.data.Dataset.from_tensor_slices((X_test_spectrogram, y_test))

# %%
test_spec_dataset = td1.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)

# %%
reg = tf.keras.regularizers.L2(l2=1.5)

# %%
tf.keras.backend.clear_session()
input_layer = Input(shape=(64,35), name = 'input_layer')
ls = LSTM(units = 128, name = 'LSTM', return_sequences = True)(input_layer)
ad = GlobalAveragePooling1D()(ls)
dc1 = Dense(1024,activation='relu',kernel_initializer=tf.keras.initializers.he_normal(seed = 30), name = 'FC1')(ad)
dc1 = Dense(256,activation='relu',kernel_initializer=tf.keras.initializers.he_normal(seed = 30), name = 'FC2')(dc1)
dc1 = BatchNormalization()(dc1)
dc1 = Dropout(0.6599)(dc1)
out = Dense(10,activation='softmax',kernel_initializer=tf.keras.initializers.glorot_normal(seed = 30), name = 'FC3')(dc1)

# %%
m_aug_spec = Model(inputs = input_layer, outputs = out)

# %%
m_aug_spec.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 64, 35)]          0
#
#  LSTM (LSTM)                 (None, 64, 128)           83968
#
#  global_average_pooling1d (G  (None, 128)              0
#  lobalAveragePooling1D)
#
#  FC1 (Dense)                 (None, 1024)              132096
#
#  FC2 (Dense)                 (None, 256)               262400
#
#  batch_normalization (BatchN  (None, 256)              1024
#  ormalization)
#
#  dropout (Dropout)           (None, 256)               0
#
#  FC3 (Dense)                 (None, 10)                2570
#
# =================================================================
# Total params: 482,058
# Trainable params: 481,546
# Non-trainable params: 512
# _________________________________________________________________

# %%
save = 'model_aug_spec_save/*.hdf5'
r = glob.glob(save)
for i in r:
    os.remove(i)

# %%
filepath="model_aug_spec_save/model-{epoch:02d}-{val_sparse_categorical_accuracy:.4f}.hdf5"
checkpoint = ModelCheckpoint(filepath=filepath, monitor='val_sparse_categorical_accuracy',  verbose=1, save_best_only=True, mode='max')
reducelr = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.055, patience = 1, verbose = 1, mode = 'min')

lrschedule = LearningRateScheduler(changeLearningRate, verbose=1)
initial_learningrate=0.001

# %%
Train_data_spec = [X_train_spectrogram, y_train]
Test_data_spec = [X_test_spectrogram, y_test]
metrics = Metrics(Train_data_spec, Test_data_spec)
callbacks = [metrics, checkpoint, reducelr, lrschedule]

# %%
m_aug_spec.compile(optimizer=tf.keras.optimizers.Adam(0.001),
              loss='sparse_categorical_crossentropy',
              metrics=['sparse_categorical_accuracy'])

# %%
model_spec_history = m_aug_spec.fit(train_spec_dataset, validation_data = test_spec_dataset, epochs=50, verbose=1, callbacks=callbacks)
# Out:
# Epoch 00001: LearningRateScheduler setting learning rate to 0.00055.
# Epoch 1/50
# 11/11 [==============================] - ETA: 0s - loss: 1.1839 - sparse_categorical_accuracy: 0.5914 - train_f1_score :  0.28285714285714286  - val_f1_score :  0.2833333333333333
#
# Epoch 00001: val_sparse_categorical_accuracy improved from 0.24667 to 0.28333, saving model to model_aug_spec_save/model-01-0.2833.hdf5
# 11/11 [==============================] - 4s 408ms/step - loss: 1.1839 - sparse_categorical_accuracy: 0.5914 - val_loss: 1.7935 - val_sparse_categorical_accuracy: 0.2833 - lr: 5.5000e-04
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.00055.
# Epoch 2/50
# 11/11 [==============================] - ETA: 0s - loss: 1.1018 - sparse_categorical_accuracy: 0.6150 - train_f1_score :  0.29714285714285715  - val_f1_score :  0.3016666666666667
#
# Epoch 00002: val_sparse_categorical_accuracy improved from 0.28333 to 0.30167, saving model to model_aug_spec_save/model-02-0.3017.hdf5
# 11/11 [==============================] - 4s 411ms/step - loss: 1.1018 - sparse_categorical_accuracy: 0.6150 - val_loss: 1.7901 - val_sparse_categorical_accuracy: 0.3017 - lr: 5.5000e-04
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.00055.
# Epoch 3/50
# 11/11 [==============================] - ETA: 0s - loss: 1.0339 - sparse_categorical_accuracy: 0.6386 - train_f1_score :  0.35714285714285715  - val_f1_score :  0.3516666666666667
#
# Epoch 00003: val_sparse_categorical_accuracy improved from 0.30167 to 0.35167, saving model to model_aug_spec_save/model-03-0.3517.hdf5
# 11/11 [==============================] - 4s 399ms/step - loss: 1.0339 - sparse_categorical_accuracy: 0.6386 - val_loss: 1.6798 - val_sparse_categorical_accuracy: 0.3517 - lr: 5.5000e-04
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.00055.
# Epoch 4/50
# 11/11 [==============================] - ETA: 0s - loss: 0.9789 - sparse_categorical_accuracy: 0.6564 - train_f1_score :  0.44142857142857145  - val_f1_score :  0.41333333333333333
#
# Epoch 00004: val_sparse_categorical_accuracy improved from 0.35167 to 0.41333, saving model to model_aug_spec_save/model-04-0.4133.hdf5
# 11/11 [==============================] - 4s 404ms/step - loss: 0.9789 - sparse_categorical_accuracy: 0.6564 - val_loss: 1.5962 - val_sparse_categorical_accuracy: 0.4133 - lr: 5.5000e-04
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.00030250000000000003.
# Epoch 5/50
# 11/11 [==============================] - ETA: 0s - loss: 0.9360 - sparse_categorical_accuracy: 0.6736 - train_f1_score :  0.45571428571428574  - val_f1_score :  0.44333333333333336
#
# Epoch 00005: val_sparse_categorical_accuracy improved from 0.41333 to 0.44333, saving model to model_aug_spec_save/model-05-0.4433.hdf5
# 11/11 [==============================] - 4s 412ms/step - loss: 0.9360 - sparse_categorical_accuracy: 0.6736 - val_loss: 1.5301 - val_sparse_categorical_accuracy: 0.4433 - lr: 3.0250e-04
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.00030250000000000003.
# Epoch 6/50
# 11/11 [==============================] - ETA: 0s - loss: 0.9141 - sparse_categorical_accuracy: 0.6900 - train_f1_score :  0.5135714285714286  - val_f1_score :  0.49666666666666665
#
# Epoch 00006: val_sparse_categorical_accuracy improved from 0.44333 to 0.49667, saving model to model_aug_spec_save/model-06-0.4967.hdf5
# 11/11 [==============================] - 4s 404ms/step - loss: 0.9141 - sparse_categorical_accuracy: 0.6900 - val_loss: 1.4284 - val_sparse_categorical_accuracy: 0.4967 - lr: 3.0250e-04
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.00030250000000000003.
# Epoch 7/50
# 11/11 [==============================] - ETA: 0s - loss: 0.8778 - sparse_categorical_accuracy: 0.7014 - train_f1_score :  0.4757142857142857  - val_f1_score :  0.4716666666666666
#
# Epoch 00007: val_sparse_categorical_accuracy did not improve from 0.49667
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 1.663750022999011e-05.
# 11/11 [==============================] - 4s 397ms/step - loss: 0.8778 - sparse_categorical_accuracy: 0.7014 - val_loss: 1.4337 - val_sparse_categorical_accuracy: 0.4717 - lr: 1.6637e-05
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.00030250000000000003.
# Epoch 8/50
# 11/11 [==============================] - ETA: 0s - loss: 0.8765 - sparse_categorical_accuracy: 0.6821 - train_f1_score :  0.53  - val_f1_score :  0.5183333333333333
#
# Epoch 00008: val_sparse_categorical_accuracy improved from 0.49667 to 0.51833, saving model to model_aug_spec_save/model-08-0.5183.hdf5
# 11/11 [==============================] - 4s 407ms/step - loss: 0.8765 - sparse_categorical_accuracy: 0.6821 - val_loss: 1.3426 - val_sparse_categorical_accuracy: 0.5183 - lr: 3.0250e-04
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.00030250000000000003.
# Epoch 9/50
# 11/11 [==============================] - ETA: 0s - loss: 0.8569 - sparse_categorical_accuracy: 0.6964 - train_f1_score :  0.5442857142857143  - val_f1_score :  0.535
#
# Epoch 00009: val_sparse_categorical_accuracy improved from 0.51833 to 0.53500, saving model to model_aug_spec_save/model-09-0.5350.hdf5
# 11/11 [==============================] - 4s 419ms/step - loss: 0.8569 - sparse_categorical_accuracy: 0.6964 - val_loss: 1.3256 - val_sparse_categorical_accuracy: 0.5350 - lr: 3.0250e-04
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.00016637500000000002.
# Epoch 10/50
# 11/11 [==============================] - ETA: 0s - loss: 0.8315 - sparse_categorical_accuracy: 0.7007 - train_f1_score :  0.6021428571428571  - val_f1_score :  0.5966666666666667
#
# Epoch 00010: val_sparse_categorical_accuracy improved from 0.53500 to 0.59667, saving model to model_aug_spec_save/model-10-0.5967.hdf5
# 11/11 [==============================] - 4s 417ms/step - loss: 0.8315 - sparse_categorical_accuracy: 0.7007 - val_loss: 1.2868 - val_sparse_categorical_accuracy: 0.5967 - lr: 1.6638e-04
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.00016637500000000002.
# Epoch 11/50
# 11/11 [==============================] - ETA: 0s - loss: 0.7989 - sparse_categorical_accuracy: 0.7164 - train_f1_score :  0.6421428571428571  - val_f1_score :  0.6166666666666667
#
# Epoch 00011: val_sparse_categorical_accuracy improved from 0.59667 to 0.61667, saving model to model_aug_spec_save/model-11-0.6167.hdf5
# 11/11 [==============================] - 4s 406ms/step - loss: 0.7989 - sparse_categorical_accuracy: 0.7164 - val_loss: 1.2459 - val_sparse_categorical_accuracy: 0.6167 - lr: 1.6638e-04
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.00016637500000000002.
# Epoch 12/50
# 11/11 [==============================] - ETA: 0s - loss: 0.7873 - sparse_categorical_accuracy: 0.7207 - train_f1_score :  0.6942857142857143  - val_f1_score :  0.6616666666666666
#
# Epoch 00012: val_sparse_categorical_accuracy improved from 0.61667 to 0.66167, saving model to model_aug_spec_save/model-12-0.6617.hdf5
# 11/11 [==============================] - 4s 408ms/step - loss: 0.7873 - sparse_categorical_accuracy: 0.7207 - val_loss: 1.1847 - val_sparse_categorical_accuracy: 0.6617 - lr: 1.6638e-04
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.00016637500000000002.
# Epoch 13/50
# 11/11 [==============================] - ETA: 0s - loss: 0.7860 - sparse_categorical_accuracy: 0.7300 - train_f1_score :  0.7157142857142856  - val_f1_score :  0.6716666666666666
#
# Epoch 00013: val_sparse_categorical_accuracy improved from 0.66167 to 0.67167, saving model to model_aug_spec_save/model-13-0.6717.hdf5
# 11/11 [==============================] - 4s 412ms/step - loss: 0.7860 - sparse_categorical_accuracy: 0.7300 - val_loss: 1.1389 - val_sparse_categorical_accuracy: 0.6717 - lr: 1.6638e-04
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.00016637500000000002.
# Epoch 14/50
# 11/11 [==============================] - ETA: 0s - loss: 0.7571 - sparse_categorical_accuracy: 0.7450 - train_f1_score :  0.7157142857142856  - val_f1_score :  0.6733333333333333
#
# Epoch 00014: val_sparse_categorical_accuracy improved from 0.67167 to 0.67333, saving model to model_aug_spec_save/model-14-0.6733.hdf5
# 11/11 [==============================] - 4s 410ms/step - loss: 0.7571 - sparse_categorical_accuracy: 0.7450 - val_loss: 1.1245 - val_sparse_categorical_accuracy: 0.6733 - lr: 1.6638e-04
#
# Epoch 00015: LearningRateScheduler setting learning rate to 9.150625000000002e-05.
# Epoch 15/50
# 11/11 [==============================] - ETA: 0s - loss: 0.7340 - sparse_categorical_accuracy: 0.7471 - train_f1_score :  0.7564285714285715  - val_f1_score :  0.72
#
# Epoch 00015: val_sparse_categorical_accuracy improved from 0.67333 to 0.72000, saving model to model_aug_spec_save/model-15-0.7200.hdf5
# 11/11 [==============================] - 4s 413ms/step - loss: 0.7340 - sparse_categorical_accuracy: 0.7471 - val_loss: 1.0645 - val_sparse_categorical_accuracy: 0.7200 - lr: 9.1506e-05
#
# Epoch 00016: LearningRateScheduler setting learning rate to 9.150625000000002e-05.
# Epoch 16/50
# 11/11 [==============================] - ETA: 0s - loss: 0.7423 - sparse_categorical_accuracy: 0.7436 - train_f1_score :  0.7771428571428571  - val_f1_score :  0.7299999999999999
#
# Epoch 00016: val_sparse_categorical_accuracy improved from 0.72000 to 0.73000, saving model to model_aug_spec_save/model-16-0.7300.hdf5
# 11/11 [==============================] - 4s 417ms/step - loss: 0.7423 - sparse_categorical_accuracy: 0.7436 - val_loss: 1.0345 - val_sparse_categorical_accuracy: 0.7300 - lr: 9.1506e-05
#
# Epoch 00017: LearningRateScheduler setting learning rate to 9.150625000000002e-05.
# Epoch 17/50
# 11/11 [==============================] - ETA: 0s - loss: 0.7205 - sparse_categorical_accuracy: 0.7436 - train_f1_score :  0.7699999999999999  - val_f1_score :  0.7299999999999999
#
# Epoch 00017: val_sparse_categorical_accuracy did not improve from 0.73000
# 11/11 [==============================] - 4s 410ms/step - loss: 0.7205 - sparse_categorical_accuracy: 0.7436 - val_loss: 1.0323 - val_sparse_categorical_accuracy: 0.7300 - lr: 9.1506e-05
#
# Epoch 00018: LearningRateScheduler setting learning rate to 9.150625000000002e-05.
# Epoch 18/50
# 11/11 [==============================] - ETA: 0s - loss: 0.7071 - sparse_categorical_accuracy: 0.7571 - train_f1_score :  0.7814285714285715  - val_f1_score :  0.7283333333333334
#
# Epoch 00018: val_sparse_categorical_accuracy did not improve from 0.73000
# 11/11 [==============================] - 4s 401ms/step - loss: 0.7071 - sparse_categorical_accuracy: 0.7571 - val_loss: 1.0070 - val_sparse_categorical_accuracy: 0.7283 - lr: 9.1506e-05
#
# Epoch 00019: LearningRateScheduler setting learning rate to 9.150625000000002e-05.
# Epoch 19/50
# 11/11 [==============================] - ETA: 0s - loss: 0.7277 - sparse_categorical_accuracy: 0.7657 - train_f1_score :  0.7964285714285714  - val_f1_score :  0.7316666666666667
#
# Epoch 00019: val_sparse_categorical_accuracy improved from 0.73000 to 0.73167, saving model to model_aug_spec_save/model-19-0.7317.hdf5
# 11/11 [==============================] - 4s 410ms/step - loss: 0.7277 - sparse_categorical_accuracy: 0.7657 - val_loss: 0.9653 - val_sparse_categorical_accuracy: 0.7317 - lr: 9.1506e-05
#
# Epoch 00020: LearningRateScheduler setting learning rate to 5.032843750000002e-05.
# Epoch 20/50
# 11/11 [==============================] - ETA: 0s - loss: 0.6945 - sparse_categorical_accuracy: 0.7607 - train_f1_score :  0.7942857142857144  - val_f1_score :  0.7416666666666667
#
# Epoch 00020: val_sparse_categorical_accuracy improved from 0.73167 to 0.74167, saving model to model_aug_spec_save/model-20-0.7417.hdf5
# 11/11 [==============================] - 4s 408ms/step - loss: 0.6945 - sparse_categorical_accuracy: 0.7607 - val_loss: 0.9557 - val_sparse_categorical_accuracy: 0.7417 - lr: 5.0328e-05
#
# Epoch 00021: LearningRateScheduler setting learning rate to 5.032843750000002e-05.
# Epoch 21/50
# 11/11 [==============================] - ETA: 0s - loss: 0.6913 - sparse_categorical_accuracy: 0.7607 - train_f1_score :  0.8085714285714286  - val_f1_score :  0.7433333333333333
#
# Epoch 00021: val_sparse_categorical_accuracy improved from 0.74167 to 0.74333, saving model to model_aug_spec_save/model-21-0.7433.hdf5
# 11/11 [==============================] - 4s 409ms/step - loss: 0.6913 - sparse_categorical_accuracy: 0.7607 - val_loss: 0.9336 - val_sparse_categorical_accuracy: 0.7433 - lr: 5.0328e-05
#
# Epoch 00022: LearningRateScheduler setting learning rate to 5.032843750000002e-05.
# Epoch 22/50
# 11/11 [==============================] - ETA: 0s - loss: 0.6712 - sparse_categorical_accuracy: 0.7621 - train_f1_score :  0.8135714285714286  - val_f1_score :  0.7533333333333333
#
# Epoch 00022: val_sparse_categorical_accuracy improved from 0.74333 to 0.75333, saving model to model_aug_spec_save/model-22-0.7533.hdf5
# 11/11 [==============================] - 4s 412ms/step - loss: 0.6712 - sparse_categorical_accuracy: 0.7621 - val_loss: 0.9082 - val_sparse_categorical_accuracy: 0.7533 - lr: 5.0328e-05
#
# Epoch 00023: LearningRateScheduler setting learning rate to 5.032843750000002e-05.
# Epoch 23/50
# 11/11 [==============================] - ETA: 0s - loss: 0.6848 - sparse_categorical_accuracy: 0.7643 - train_f1_score :  0.8157142857142857  - val_f1_score :  0.7533333333333333
#
# Epoch 00023: val_sparse_categorical_accuracy did not improve from 0.75333
# 11/11 [==============================] - 5s 485ms/step - loss: 0.6848 - sparse_categorical_accuracy: 0.7643 - val_loss: 0.8998 - val_sparse_categorical_accuracy: 0.7533 - lr: 5.0328e-05
#
# Epoch 00024: LearningRateScheduler setting learning rate to 5.032843750000002e-05.
# Epoch 24/50
# 11/11 [==============================] - ETA: 0s - loss: 0.6781 - sparse_categorical_accuracy: 0.7679 - train_f1_score :  0.8257142857142856  - val_f1_score :  0.7633333333333333
#
# Epoch 00024: val_sparse_categorical_accuracy improved from 0.75333 to 0.76333, saving model to model_aug_spec_save/model-24-0.7633.hdf5
# 11/11 [==============================] - 4s 413ms/step - loss: 0.6781 - sparse_categorical_accuracy: 0.7679 - val_loss: 0.8806 - val_sparse_categorical_accuracy: 0.7633 - lr: 5.0328e-05
#
# Epoch 00025: LearningRateScheduler setting learning rate to 2.768064062500001e-05.
# Epoch 25/50
# 11/11 [==============================] - ETA: 0s - loss: 0.6607 - sparse_categorical_accuracy: 0.7821 - train_f1_score :  0.8292857142857143  - val_f1_score :  0.765
#
# Epoch 00025: val_sparse_categorical_accuracy improved from 0.76333 to 0.76500, saving model to model_aug_spec_save/model-25-0.7650.hdf5
# 11/11 [==============================] - 4s 409ms/step - loss: 0.6607 - sparse_categorical_accuracy: 0.7821 - val_loss: 0.8634 - val_sparse_categorical_accuracy: 0.7650 - lr: 2.7681e-05
#
# Epoch 00026: LearningRateScheduler setting learning rate to 2.768064062500001e-05.
# Epoch 26/50
# 11/11 [==============================] - ETA: 0s - loss: 0.6628 - sparse_categorical_accuracy: 0.7821 - train_f1_score :  0.8278571428571427  - val_f1_score :  0.765
#
# Epoch 00026: val_sparse_categorical_accuracy did not improve from 0.76500
# 11/11 [==============================] - 4s 410ms/step - loss: 0.6628 - sparse_categorical_accuracy: 0.7821 - val_loss: 0.8503 - val_sparse_categorical_accuracy: 0.7650 - lr: 2.7681e-05
#
# Epoch 00027: LearningRateScheduler setting learning rate to 2.768064062500001e-05.
# Epoch 27/50
# 11/11 [==============================] - ETA: 0s - loss: 0.6666 - sparse_categorical_accuracy: 0.7771 - train_f1_score :  0.8314285714285714  - val_f1_score :  0.7616666666666667
#
# Epoch 00027: val_sparse_categorical_accuracy did not improve from 0.76500
# 11/11 [==============================] - 4s 402ms/step - loss: 0.6666 - sparse_categorical_accuracy: 0.7771 - val_loss: 0.8342 - val_sparse_categorical_accuracy: 0.7617 - lr: 2.7681e-05
#
# Epoch 00028: LearningRateScheduler setting learning rate to 2.768064062500001e-05.
# Epoch 28/50
# 11/11 [==============================] - ETA: 0s - loss: 0.6806 - sparse_categorical_accuracy: 0.7707 - train_f1_score :  0.8307142857142857  - val_f1_score :  0.7633333333333333
#
# Epoch 00028: val_sparse_categorical_accuracy did not improve from 0.76500
# 11/11 [==============================] - 4s 404ms/step - loss: 0.6806 - sparse_categorical_accuracy: 0.7707 - val_loss: 0.8233 - val_sparse_categorical_accuracy: 0.7633 - lr: 2.7681e-05
#
# Epoch 00029: LearningRateScheduler setting learning rate to 2.768064062500001e-05.
# Epoch 29/50
# 11/11 [==============================] - ETA: 0s - loss: 0.6625 - sparse_categorical_accuracy: 0.7786 - train_f1_score :  0.8421428571428572  - val_f1_score :  0.7633333333333333
#
# Epoch 00029: val_sparse_categorical_accuracy did not improve from 0.76500
# 11/11 [==============================] - 4s 404ms/step - loss: 0.6625 - sparse_categorical_accuracy: 0.7786 - val_loss: 0.8088 - val_sparse_categorical_accuracy: 0.7633 - lr: 2.7681e-05
#
# Epoch 00030: LearningRateScheduler setting learning rate to 1.5224352343750007e-05.
# Epoch 30/50
# 11/11 [==============================] - ETA: 0s - loss: 0.6541 - sparse_categorical_accuracy: 0.7700 - train_f1_score :  0.8435714285714284  - val_f1_score :  0.7683333333333333
#
# Epoch 00030: val_sparse_categorical_accuracy improved from 0.76500 to 0.76833, saving model to model_aug_spec_save/model-30-0.7683.hdf5
# 11/11 [==============================] - 4s 404ms/step - loss: 0.6541 - sparse_categorical_accuracy: 0.7700 - val_loss: 0.8004 - val_sparse_categorical_accuracy: 0.7683 - lr: 1.5224e-05
#
# Epoch 00031: LearningRateScheduler setting learning rate to 1.5224352343750007e-05.
# Epoch 31/50
# 11/11 [==============================] - ETA: 0s - loss: 0.6629 - sparse_categorical_accuracy: 0.7764 - train_f1_score :  0.8399999999999999  - val_f1_score :  0.7733333333333333
#
# Epoch 00031: val_sparse_categorical_accuracy improved from 0.76833 to 0.77333, saving model to model_aug_spec_save/model-31-0.7733.hdf5
# 11/11 [==============================] - 4s 410ms/step - loss: 0.6629 - sparse_categorical_accuracy: 0.7764 - val_loss: 0.7956 - val_sparse_categorical_accuracy: 0.7733 - lr: 1.5224e-05
#
# Epoch 00032: LearningRateScheduler setting learning rate to 1.5224352343750007e-05.
# Epoch 32/50
# 11/11 [==============================] - ETA: 0s - loss: 0.6619 - sparse_categorical_accuracy: 0.7829 - train_f1_score :  0.8385714285714285  - val_f1_score :  0.7783333333333333
#
# Epoch 00032: val_sparse_categorical_accuracy improved from 0.77333 to 0.77833, saving model to model_aug_spec_save/model-32-0.7783.hdf5
# 11/11 [==============================] - 4s 414ms/step - loss: 0.6619 - sparse_categorical_accuracy: 0.7829 - val_loss: 0.7919 - val_sparse_categorical_accuracy: 0.7783 - lr: 1.5224e-05
#
# Epoch 00033: LearningRateScheduler setting learning rate to 1.5224352343750007e-05.
# Epoch 33/50
# 11/11 [==============================] - ETA: 0s - loss: 0.6791 - sparse_categorical_accuracy: 0.7650 - train_f1_score :  0.8414285714285715  - val_f1_score :  0.78
#
# Epoch 00033: val_sparse_categorical_accuracy improved from 0.77833 to 0.78000, saving model to model_aug_spec_save/model-33-0.7800.hdf5
# 11/11 [==============================] - 4s 400ms/step - loss: 0.6791 - sparse_categorical_accuracy: 0.7650 - val_loss: 0.7855 - val_sparse_categorical_accuracy: 0.7800 - lr: 1.5224e-05
#
# Epoch 00034: LearningRateScheduler setting learning rate to 1.5224352343750007e-05.
# Epoch 34/50
# 11/11 [==============================] - ETA: 0s - loss: 0.6530 - sparse_categorical_accuracy: 0.7821 - train_f1_score :  0.8428571428571429  - val_f1_score :  0.775
#
# Epoch 00034: val_sparse_categorical_accuracy did not improve from 0.78000
# 11/11 [==============================] - 4s 405ms/step - loss: 0.6530 - sparse_categorical_accuracy: 0.7821 - val_loss: 0.7778 - val_sparse_categorical_accuracy: 0.7750 - lr: 1.5224e-05
#
# Epoch 00035: LearningRateScheduler setting learning rate to 8.373393789062505e-06.
# Epoch 35/50
# 11/11 [==============================] - ETA: 0s - loss: 0.6718 - sparse_categorical_accuracy: 0.7700 - train_f1_score :  0.8464285714285714  - val_f1_score :  0.7716666666666666
#
# Epoch 00035: val_sparse_categorical_accuracy did not improve from 0.78000
# 11/11 [==============================] - 4s 406ms/step - loss: 0.6718 - sparse_categorical_accuracy: 0.7700 - val_loss: 0.7720 - val_sparse_categorical_accuracy: 0.7717 - lr: 8.3734e-06
#
# Epoch 00036: LearningRateScheduler setting learning rate to 8.373393789062505e-06.
# Epoch 36/50
# 11/11 [==============================] - ETA: 0s - loss: 0.6617 - sparse_categorical_accuracy: 0.7657 - train_f1_score :  0.8485714285714285  - val_f1_score :  0.7716666666666666
#
# Epoch 00036: val_sparse_categorical_accuracy did not improve from 0.78000
# 11/11 [==============================] - 4s 409ms/step - loss: 0.6617 - sparse_categorical_accuracy: 0.7657 - val_loss: 0.7673 - val_sparse_categorical_accuracy: 0.7717 - lr: 8.3734e-06
#
# Epoch 00037: LearningRateScheduler setting learning rate to 8.373393789062505e-06.
# Epoch 37/50
# 11/11 [==============================] - ETA: 0s - loss: 0.6488 - sparse_categorical_accuracy: 0.7957 - train_f1_score :  0.8471428571428571  - val_f1_score :  0.775
#
# Epoch 00037: val_sparse_categorical_accuracy did not improve from 0.78000
# 11/11 [==============================] - 4s 418ms/step - loss: 0.6488 - sparse_categorical_accuracy: 0.7957 - val_loss: 0.7626 - val_sparse_categorical_accuracy: 0.7750 - lr: 8.3734e-06
#
# Epoch 00038: LearningRateScheduler setting learning rate to 8.373393789062505e-06.
# Epoch 38/50
# 11/11 [==============================] - ETA: 0s - loss: 0.6549 - sparse_categorical_accuracy: 0.7757 - train_f1_score :  0.8485714285714285  - val_f1_score :  0.7716666666666666
#
# Epoch 00038: val_sparse_categorical_accuracy did not improve from 0.78000
# 11/11 [==============================] - 4s 404ms/step - loss: 0.6549 - sparse_categorical_accuracy: 0.7757 - val_loss: 0.7579 - val_sparse_categorical_accuracy: 0.7717 - lr: 8.3734e-06
#
# Epoch 00039: LearningRateScheduler setting learning rate to 8.373393789062505e-06.
# Epoch 39/50
# 11/11 [==============================] - ETA: 0s - loss: 0.6618 - sparse_categorical_accuracy: 0.7743 - train_f1_score :  0.8492857142857143  - val_f1_score :  0.7716666666666666
#
# Epoch 00039: val_sparse_categorical_accuracy did not improve from 0.78000
# 11/11 [==============================] - 4s 413ms/step - loss: 0.6618 - sparse_categorical_accuracy: 0.7743 - val_loss: 0.7543 - val_sparse_categorical_accuracy: 0.7717 - lr: 8.3734e-06
#
# Epoch 00040: LearningRateScheduler setting learning rate to 4.605366583984378e-06.
# Epoch 40/50
# 11/11 [==============================] - ETA: 0s - loss: 0.6784 - sparse_categorical_accuracy: 0.7657 - train_f1_score :  0.8471428571428571  - val_f1_score :  0.7783333333333333
#
# Epoch 00040: val_sparse_categorical_accuracy did not improve from 0.78000
# 11/11 [==============================] - 4s 402ms/step - loss: 0.6784 - sparse_categorical_accuracy: 0.7657 - val_loss: 0.7520 - val_sparse_categorical_accuracy: 0.7783 - lr: 4.6054e-06
#
# Epoch 00041: LearningRateScheduler setting learning rate to 4.605366583984378e-06.
# Epoch 41/50
# 11/11 [==============================] - ETA: 0s - loss: 0.6601 - sparse_categorical_accuracy: 0.7736 - train_f1_score :  0.8478571428571429  - val_f1_score :  0.7783333333333333
#
# Epoch 00041: val_sparse_categorical_accuracy did not improve from 0.78000
# 11/11 [==============================] - 4s 403ms/step - loss: 0.6601 - sparse_categorical_accuracy: 0.7736 - val_loss: 0.7498 - val_sparse_categorical_accuracy: 0.7783 - lr: 4.6054e-06
#
# Epoch 00042: LearningRateScheduler setting learning rate to 4.605366583984378e-06.
# Epoch 42/50
# 11/11 [==============================] - ETA: 0s - loss: 0.6589 - sparse_categorical_accuracy: 0.7736 - train_f1_score :  0.8492857142857143  - val_f1_score :  0.7766666666666666
#
# Epoch 00042: val_sparse_categorical_accuracy did not improve from 0.78000
# 11/11 [==============================] - 4s 399ms/step - loss: 0.6589 - sparse_categorical_accuracy: 0.7736 - val_loss: 0.7474 - val_sparse_categorical_accuracy: 0.7767 - lr: 4.6054e-06
#
# Epoch 00043: LearningRateScheduler setting learning rate to 4.605366583984378e-06.
# Epoch 43/50
# 11/11 [==============================] - ETA: 0s - loss: 0.6453 - sparse_categorical_accuracy: 0.7936 - train_f1_score :  0.8521428571428571  - val_f1_score :  0.7766666666666666
#
# Epoch 00043: val_sparse_categorical_accuracy did not improve from 0.78000
# 11/11 [==============================] - 4s 398ms/step - loss: 0.6453 - sparse_categorical_accuracy: 0.7936 - val_loss: 0.7449 - val_sparse_categorical_accuracy: 0.7767 - lr: 4.6054e-06
#
# Epoch 00044: LearningRateScheduler setting learning rate to 4.605366583984378e-06.
# Epoch 44/50
# 11/11 [==============================] - ETA: 0s - loss: 0.6506 - sparse_categorical_accuracy: 0.7800 - train_f1_score :  0.8507142857142858  - val_f1_score :  0.7766666666666666
#
# Epoch 00044: val_sparse_categorical_accuracy did not improve from 0.78000
# 11/11 [==============================] - 4s 410ms/step - loss: 0.6506 - sparse_categorical_accuracy: 0.7800 - val_loss: 0.7429 - val_sparse_categorical_accuracy: 0.7767 - lr: 4.6054e-06
#
# Epoch 00045: LearningRateScheduler setting learning rate to 2.532951621191408e-06.
# Epoch 45/50
# 11/11 [==============================] - ETA: 0s - loss: 0.6740 - sparse_categorical_accuracy: 0.7657 - train_f1_score :  0.8514285714285714  - val_f1_score :  0.7733333333333333
#
# Epoch 00045: val_sparse_categorical_accuracy did not improve from 0.78000
# 11/11 [==============================] - 4s 407ms/step - loss: 0.6740 - sparse_categorical_accuracy: 0.7657 - val_loss: 0.7411 - val_sparse_categorical_accuracy: 0.7733 - lr: 2.5330e-06
#
# Epoch 00046: LearningRateScheduler setting learning rate to 2.532951621191408e-06.
# Epoch 46/50
# 11/11 [==============================] - ETA: 0s - loss: 0.6542 - sparse_categorical_accuracy: 0.7829 - train_f1_score :  0.8507142857142858  - val_f1_score :  0.775
#
# Epoch 00046: val_sparse_categorical_accuracy did not improve from 0.78000
# 11/11 [==============================] - 4s 412ms/step - loss: 0.6542 - sparse_categorical_accuracy: 0.7829 - val_loss: 0.7397 - val_sparse_categorical_accuracy: 0.7750 - lr: 2.5330e-06
#
# Epoch 00047: LearningRateScheduler setting learning rate to 2.532951621191408e-06.
# Epoch 47/50
# 11/11 [==============================] - ETA: 0s - loss: 0.6550 - sparse_categorical_accuracy: 0.7786 - train_f1_score :  0.8492857142857143  - val_f1_score :  0.7766666666666666
#
# Epoch 00047: val_sparse_categorical_accuracy did not improve from 0.78000
# 11/11 [==============================] - 4s 407ms/step - loss: 0.6550 - sparse_categorical_accuracy: 0.7786 - val_loss: 0.7385 - val_sparse_categorical_accuracy: 0.7767 - lr: 2.5330e-06
#
# Epoch 00048: LearningRateScheduler setting learning rate to 2.532951621191408e-06.
# Epoch 48/50
# 11/11 [==============================] - ETA: 0s - loss: 0.6548 - sparse_categorical_accuracy: 0.7879 - train_f1_score :  0.8507142857142858  - val_f1_score :  0.7766666666666666
#
# Epoch 00048: val_sparse_categorical_accuracy did not improve from 0.78000
# 11/11 [==============================] - 4s 404ms/step - loss: 0.6548 - sparse_categorical_accuracy: 0.7879 - val_loss: 0.7375 - val_sparse_categorical_accuracy: 0.7767 - lr: 2.5330e-06
#
# Epoch 00049: LearningRateScheduler setting learning rate to 2.532951621191408e-06.
# Epoch 49/50
# 11/11 [==============================] - ETA: 0s - loss: 0.6389 - sparse_categorical_accuracy: 0.7864 - train_f1_score :  0.8514285714285714  - val_f1_score :  0.775
#
# Epoch 00049: val_sparse_categorical_accuracy did not improve from 0.78000
# 11/11 [==============================] - 4s 408ms/step - loss: 0.6389 - sparse_categorical_accuracy: 0.7864 - val_loss: 0.7361 - val_sparse_categorical_accuracy: 0.7750 - lr: 2.5330e-06
#
# Epoch 00050: LearningRateScheduler setting learning rate to 1.3931233916552745e-06.
# Epoch 50/50
# 11/11 [==============================] - ETA: 0s - loss: 0.6396 - sparse_categorical_accuracy: 0.7857 - train_f1_score :  0.8507142857142858  - val_f1_score :  0.775
#
# Epoch 00050: val_sparse_categorical_accuracy did not improve from 0.78000
# 11/11 [==============================] - 4s 408ms/step - loss: 0.6396 - sparse_categorical_accuracy: 0.7857 - val_loss: 0.7349 - val_sparse_categorical_accuracy: 0.7750 - lr: 1.3931e-06

# %%
acc = model_spec_history.history['sparse_categorical_accuracy']
val_acc = model_spec_history.history['val_sparse_categorical_accuracy']

loss = model_spec_history.history['loss']
val_loss = model_spec_history.history['val_loss']

f1 = metrics.history['train_f1_score']
val_f1 = metrics.history['val_f1_score']

epochs_range = range(50)

#plt.figure(figsize=(8, 8))
#plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.show()

plt.plot(epochs_range, f1, label='Training micro F1 score')
plt.plot(epochs_range, val_f1, label='Validation micro F1 score')
plt.legend(loc='lower right')
plt.title('Training and Validation F1 Score')
plt.show()

#plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
## as discussed above, please write the LSTM
y_pred = m_aug_spec.predict(X_test_spectrogram)
y_pred = np.argmax(y_pred, axis = 1)
#p = p.round()

# %%
print('Classification Report')
print(classification_report(y_test, y_pred))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.81      0.87      0.84        60
#            1       0.81      0.83      0.82        60
#            2       0.68      0.73      0.70        60
#            3       0.58      0.62      0.60        60
#            4       0.88      0.77      0.82        60
#            5       0.77      0.80      0.79        60
#            6       0.78      0.77      0.77        60
#            7       0.76      0.62      0.68        60
#            8       0.85      0.83      0.84        60
#            9       0.86      0.92      0.89        60
#
#     accuracy                           0.78       600
#    macro avg       0.78      0.78      0.77       600
# weighted avg       0.78      0.78      0.77       600

# %%
ax= plt.subplot()
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, ax = ax, fmt='g', cmap='Greens') #annot=True to annotate cells

# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels') 
ax.set_title('Confusion Matrix')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
m_aug_spec.save('Model_Aug_Spect_2_0.805_final.h5')

# %%
plot_model(m_aug_spec, show_shapes=True, show_layer_names=True)

# %% [markdown]
# Observation:
#
# 1.   Micro F1 score for model 1 is: 0.10000000000
# 2.   Micro F1 score for model 2 is: 0.80241004573
# 3.   Micro F1 score for model 3 is: 0.10214937002
# 4.   Micro F1 score for model 4 is: 0.87520014689
#
# Spectrogram data gives good F1 score than using raw data.
